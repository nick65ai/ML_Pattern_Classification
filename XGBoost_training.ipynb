# %%
from BirdExplore import BirdsData
import os
import seaborn as sns
import pandas as pd
from matplotlib import pyplot as plt
import numpy as np

from sklearn.decomposition import PCA
from sklearn.preprocessing import StandardScaler
from sklearn.preprocessing import MinMaxScaler
from sklearn.model_selection import train_test_split

from sklearn.linear_model import SGDClassifier, LogisticRegression
from sklearn.neighbors import KNeighborsClassifier
from sklearn.tree import DecisionTreeClassifier
from sklearn.ensemble import RandomForestClassifier
from sklearn.svm import SVC
from sklearn.ensemble import AdaBoostClassifier
from sklearn.model_selection import StratifiedKFold
from sklearn.metrics import confusion_matrix, classification_report,accuracy_score,average_precision_score,f1_score
from sklearn.model_selection import cross_val_score, KFold
import xgboost as xgb
import GPUtil
from sklearn.metrics import auc, accuracy_score, confusion_matrix, mean_squared_error
GPUtil.getAvailable()
# Out:
# [0]

# %%
full_df = BirdsData('ptichki').get_dataframe()
full_df = full_df.sample(frac=1) #shuffle dataset randomly
class_labels = {
    0: 'other',
    1: 'comcuc',
    2: 'cowpig1',
    3: 'eucdov',
    4: 'eueowl1',
    5: 'grswoo',
    6: 'tawowl1'
}
# print(full_df)
#FILTER DATASET. LEAVE JUST MOST IMPORTANT FEATURES
df_filtered = full_df.filter(like='cln_melspect_mean') \
                .join(full_df.filter(like='cln_contrast_mean')) \
                .join(full_df.filter(like='cln_mfcc_mean'))\
                .join(full_df.filter(like='cln_power_mean'))\
                .join(full_df.filter(like='cln_energy_mean')) \
                .join(full_df.filter(like='cln_centroid_mean'))\
                .join(full_df.filter(like='cln_flatness_mean')) \
                .join(full_df.filter(like='cln_melspect_std'))\
                .join(full_df.filter(like='cln_mfcc_std')) \
                .join(full_df.filter(like='raw_contrast_mean'))\
                .join(full_df.filter(like='raw_melspect_mean')) \
                .join(full_df.filter(like='raw_mfcc_mean'))\
                .join(full_df.filter(like='raw_flux_std')) \
                .join(full_df.filter(like='raw_melspect_std'))\
                .join(full_df.filter(like='raw_mfcc_std')) \
                .join(full_df.filter(like='raw_power_std'))\
                .join(full_df.filter(like='raw_energy_std')) \
                .join(full_df.filter(like='yin'))\
                .join(full_df['target'])   
full_df = df_filtered

#FOR XHG BOOST. CHANGE OUR TARGET FROM NAMES TO NUMBERS
for i,class_name in enumerate(class_labels.values()):
    full_df['target'] = full_df['target'].replace(str(class_name), i)

#DELETE TARGET COLUMN FROM OUR DATASET. GET ONLY LABELS COLUMN. WILL BE USED FOR CLASSIFICATION
labels = full_df['target']
del full_df['target']
print(full_df.columns)
print(type(full_df))
print(type(labels))

#SCALE DATA
# min_max_scaler = MinMaxScaler()
# full_df_scaled = min_max_scaler.fit_transform(full_df)

# full_df = pd.DataFrame(full_df_scaled, columns=full_df.columns)
# print(full_df)
# print(full_df.shape)

# df = pd.DataFrame(full_df)
# print(df.shape)
# print(type(df))

# %%
full_df = BirdsData('ptichki').get_dataframe()
class_labels = {
    0: 'other',
    1: 'comcuc',
    2: 'cowpig1',
    3: 'eucdov',
    4: 'eueowl1',
    5: 'grswoo',
    6: 'tawowl1'
}
for i,class_name in enumerate(class_labels.values()):
    full_df['target'] = full_df['target'].replace(str(class_name), i)
labels = full_df['target']
del full_df['target']

# %% [markdown]
# <h1>Train multiple classifiers and determine the best among them</h1>

# %%
from sklearn.naive_bayes import GaussianNB
from sklearn.linear_model import SGDClassifier, LogisticRegression
from sklearn.neighbors import KNeighborsClassifier
from sklearn.tree import DecisionTreeClassifier
from sklearn.ensemble import RandomForestClassifier
from sklearn.svm import SVC
from sklearn.neural_network import MLPClassifier
def model_assess(model,x_train,y_train,x_test,y_test, title = "Default"):
    model.fit(x_train, y_train)
    preds = model.predict(x_test)
    print('Accuracy', title, ':', round(accuracy_score(y_test, preds), 5), '\n')
# Naive Bayes
nb = GaussianNB()
model_assess(nb, "Naive Bayes")

# Stochastic Gradient Descent
sgd = SGDClassifier(max_iter=5000, random_state=0)
model_assess(sgd, "Stochastic Gradient Descent")

# KNN
knn = KNeighborsClassifier(n_neighbors=19)
model_assess(knn, "KNN")

# Decission trees
tree = DecisionTreeClassifier()
model_assess(tree, "Decission trees")

# Random Forest
rforest = RandomForestClassifier(n_estimators=1000, max_depth=10, random_state=0)
model_assess(rforest, "Random Forest")

# Support Vector Machine
svm = SVC(decision_function_shape="ovo")
model_assess(svm, "Support Vector Machine")

# Logistic Regression
lg = LogisticRegression(random_state=0, solver='lbfgs', multi_class='multinomial')
model_assess(lg, "Logistic Regression")

# Neural Nets
nn = MLPClassifier(solver='lbfgs', alpha=1e-5, hidden_layer_sizes=(5000, 10), random_state=1)
model_assess(nn, "Neural Nets")

params = {
            'objective':'binary:logistic',
            'max_depth': 10,
            'alpha': 10,
            'learning_rate': 1.0,
            'n_estimators':1000,
            'tree_method':'gpu_hist'
        } 
# Cross Gradient Booster
xgb = xgb.XGBClassifier(**params)
model_assess(xgb, "Cross Gradient Booster")

# Cross Gradient Booster (Random Forest)
xgbrf = xgb.XGBRFClassifier(objective= 'multi:softmax')
model_assess(xgbrf, "Cross Gradient Booster (Random Forest)")

# %% [markdown]
# <h2>Training XGBoost model</h2>

# %%
def plot_compare(metrics,eval_results,epochs):
    for m in metrics:
        test_score = eval_results['val'][m]
        train_score = eval_results['train'][m]
        rang = range(0, epochs)
        plt.rcParams["figure.figsize"] = [6,6]
        plt.plot(rang, test_score,"c", label="Val")
        plt.plot(rang, train_score,"orange", label="Train")
        title_name = m + " plot"
        plt.title(title_name)
        plt.xlabel('Iterations')
        plt.ylabel(m)
        lgd = plt.legend()
        plt.show()

# %%
# params = {
#         'objective':'multi:softmax',
#         'max_depth': 5,
#         'subsample':0.8,
#         'colsample_bytree':0.8,
#         'min_child_weight':1,
#         'gamma':0,
#         'nthread':4,
#         'learning_rate': 0.1,
#         'num_class':7,
#         'predictor':'gpu_predictor',
#         'tree_method':'gpu_hist',
#         'n_estimators':1000,
#     }   

# def display_scores(scores):
#     print("Scores: {0}\nMean: {1:.3f}\nStd: {2:.3f}".format(scores, np.mean(scores), np.std(scores)))

# scores = []
# VER = 1
# skf = KFold(n_splits=4, shuffle=True)
# for fold,(train_idx, valid_idx) in enumerate(skf.split(
#             full_df, labels )):
#     print('#'*25)
#     print('### Fold',fold+1)
#     print('### Train size',len(train_idx),'Valid size',len(valid_idx))
#     print('#'*25)

#     X_train = full_df.loc[train_idx]
#     y_train = labels.loc[train_idx]
#     X_valid = full_df.loc[valid_idx]
#     y_valid = labels.loc[valid_idx]
    
#     # dtrain = xgb.DMatrix(data=X_train, label=y_train)
#     # dvalid = xgb.DMatrix(data=X_valid, label=y_valid)

#     xgb_model = xgb.XGBClassifier(**params)
#     xgb_model.fit(X_train, y_train,eval_set=[(X_valid, y_valid)],verbose=2)
#     y_pred = xgb_model.predict(X_valid)
#     scores.append(accuracy_score(y_pred, y_valid))
#     xgb_model.save_model(f'XGB_v{VER}_fold{fold}.xgb')
    
#     del X_train,y_train
#     del X_valid, y_valid
    
# print(scores)
# display_scores(scores)

# %% [markdown]
# BEST TRAINING

# %% [markdown]
# We want to find best hyperparameters for our model

# %%
xgb_model.predict(X_test)

# %%
X_train, X_hyp, y_train, y_hyp = train_test_split(full_df, labels, test_size = 0.5, random_state = 0)
X_train, X_test, y_train, y_test = train_test_split(X_hyp, y_hyp, test_size = 0.7, random_state = 0)

# %%
from hyperopt import fmin, tpe, hp,Trials,STATUS_OK,space_eval

space = {
    'objective':hp.choice('objective',['multi:softmax']),
    'learning_rate': hp.choice('learning_rate', [0.0001, 0.01, 0.1, 1]),
    'max_depth' : hp.choice('max_depth', range(3,10,2)),
    'gamma' : hp.choice('gamma', [i/10.0 for i in range(0,5)]),
    'colsample_bytree' : hp.choice('colsample_bytree', [i/10.0 for i in range(3,10)]),     
    'reg_alpha' : hp.choice('reg_alpha', [1e-5, 0.1, 1, 10]), 
    'reg_lambda' : hp.choice('reg_lambda', [1e-5, 0.1, 1, 10]),
    'num_class':7,
    'n_estimators':hp.choice('n_estimators', [400,700,1000,1300]),
}

kfold = StratifiedKFold(n_splits=5, shuffle=True, random_state=0)

def objective(params):
    xgboost = xgb.XGBClassifier(seed=0,predictor='gpu_predictor',tree_method='gpu_hist', **params)
    xgboost.fit(X_train, y_train)
    score = f1_score(y_test, xgboost.predict(X_test), average='micro')
    loss = - score
    print(loss)
    return {'loss': loss, 'params': params,'status':STATUS_OK}

best = fmin(fn = objective, space = space, algo = tpe.suggest, max_evals = 48, trials = Trials())
best_params = space_eval(space, best)
print('Best_Params:',best_params)
# Out:
# -0.8803095238095238
# -0.8937619047619048
# -0.9092142857142858
# -0.9004285714285715
# -0.8417857142857142
# -0.8759047619047619
# -0.9064761904761904
# -0.9078095238095238
# -0.8878809523809523
# -0.8825
# -0.8950238095238096
# -0.9066904761904762
# -0.8938571428571429
# -0.9073333333333333
# -0.908547619047619
# -0.9048333333333334
# -0.9048333333333334
# -0.9143095238095237
# -0.8966190476190476
# -0.9101428571428571
# -0.904
# -0.9051428571428571
# -0.9101428571428571
# -0.9066190476190475
# -0.9101428571428571
# -0.9123333333333333
# -0.8689285714285714
# -0.9123333333333333
# -0.8750714285714285
# -0.912
# -0.9031904761904761
# -0.9123095238095237
# -0.9050952380952381
# -0.8667142857142857
# -0.9118571428571427
# -0.9037619047619048
# -0.9056666666666666
# -0.8728809523809524
# -0.8936666666666667
# -0.9035952380952381
# -0.907404761904762
# -0.8878809523809523
# -0.9075238095238095
# -0.8722619047619048
# -0.9015238095238095
# -0.9125
# -0.8777380952380952
# -0.9067380952380952
# 100%|██████████| 48/48 [1:07:14<00:00, 84.05s/trial, best loss: -0.9143095238095237]
# Best_Params: {'colsample_bytree': 0.5, 'gamma': 0.0, 'learning_rate': 0.1, 'max_depth': 5, 'n_estimators': 700, 'num_class': 7, 'objective': 'multi:softmax', 'reg_alpha': 1e-05, 'reg_lambda': 1e-05}

# %% [markdown]
# We now peform Cross validation and see how our parameters perform

# %%
#Best_Params: {'colsample_bytree': 0.5, 'gamma': 0.0, 'learning_rate': 0.1, 'max_depth': 5, 'n_estimators': 700, 'num_class': 7, 'objective': 'multi:softmax', 'reg_alpha': 1e-05, 'reg_lambda': 1e-05}


scores = []
VER = 1
skf = StratifiedKFold(n_splits=5, shuffle=True,random_state=0)
for fold,(train_idx, valid_idx) in enumerate(skf.split(
            full_df, labels )):
    print('#'*25)
    print('### Fold',fold+1)
    print('### Train size',len(train_idx),'Valid size',len(valid_idx))
    print('#'*25)

    X_train = full_df.loc[train_idx]
    y_train = labels.loc[train_idx]
    X_valid = full_df.loc[valid_idx]
    y_valid = labels.loc[valid_idx]
    
    # dtrain = xgb.DMatrix(data=X_train, label=y_train)
    # dvalid = xgb.DMatrix(data=X_valid, label=y_valid)

    xgb_model_opt = xgb.XGBClassifier(seed=0, 
                            colsample_bytree=space_eval(space, best)['colsample_bytree'], 
                            objective=space_eval(space, best)['objective'],
                            gamma=space_eval(space, best)['gamma'], 
                            learning_rate=space_eval(space, best)['learning_rate'], 
                            max_depth=space_eval(space, best)['max_depth'], 
                            reg_alpha=space_eval(space, best)['reg_alpha'],
                            reg_lambda=space_eval(space, best)['reg_lambda'],
                            n_estimators=space_eval(space, best)['n_estimators'],
                            tree_method='gpu_hist',
                            predictor='gpu_predictor',
                            nthread=6,
                            num_class=7
                            )


    xgb_model_opt.fit(X_train, y_train,eval_set=[(X_valid, y_valid)],verbose=2)
    y_pred = xgb_model_opt.predict(X_valid)
    scores.append(accuracy_score(y_pred, y_valid))
    xgb_model_opt.save_model(f'XGB_optimal_fold{fold}.xgb')
    
    del X_train,y_train
    del X_valid, y_valid
print(scores)
# Out:
# #########################
# ### Fold 1
# ### Train size 96000 Valid size 24000
# #########################
# [0]	validation_0-mlogloss:1.70732
# [2]	validation_0-mlogloss:1.38300
# [4]	validation_0-mlogloss:1.16277
# [6]	validation_0-mlogloss:1.00186
# [8]	validation_0-mlogloss:0.87976
# [10]	validation_0-mlogloss:0.78184
# [12]	validation_0-mlogloss:0.70368
# [14]	validation_0-mlogloss:0.63997
# [16]	validation_0-mlogloss:0.58814
# [18]	validation_0-mlogloss:0.54520
# [20]	validation_0-mlogloss:0.50977
# [22]	validation_0-mlogloss:0.47997
# [24]	validation_0-mlogloss:0.45493
# [26]	validation_0-mlogloss:0.43355
# [28]	validation_0-mlogloss:0.41499
# [30]	validation_0-mlogloss:0.39939
# [32]	validation_0-mlogloss:0.38564
# [34]	validation_0-mlogloss:0.37362
# [36]	validation_0-mlogloss:0.36328
# [38]	validation_0-mlogloss:0.35378
# [40]	validation_0-mlogloss:0.34532
# [42]	validation_0-mlogloss:0.33796
# [44]	validation_0-mlogloss:0.33118
# [46]	validation_0-mlogloss:0.32506
# [48]	validation_0-mlogloss:0.31951
# [50]	validation_0-mlogloss:0.31420
# [52]	validation_0-mlogloss:0.30955
# [54]	validation_0-mlogloss:0.30517
# [56]	validation_0-mlogloss:0.30092
# [58]	validation_0-mlogloss:0.29715
# [60]	validation_0-mlogloss:0.29358
# [62]	validation_0-mlogloss:0.29042
# [64]	validation_0-mlogloss:0.28752
# [66]	validation_0-mlogloss:0.28426
# [68]	validation_0-mlogloss:0.28155
# [70]	validation_0-mlogloss:0.27914
# [72]	validation_0-mlogloss:0.27662
# [74]	validation_0-mlogloss:0.27417
# [76]	validation_0-mlogloss:0.27184
# [78]	validation_0-mlogloss:0.26966
# [80]	validation_0-mlogloss:0.26751
# [82]	validation_0-mlogloss:0.26543
# [84]	validation_0-mlogloss:0.26372
# [86]	validation_0-mlogloss:0.26190
# [88]	validation_0-mlogloss:0.25994
# [90]	validation_0-mlogloss:0.25829
# [92]	validation_0-mlogloss:0.25669
# [94]	validation_0-mlogloss:0.25493
# [96]	validation_0-mlogloss:0.25321
# [98]	validation_0-mlogloss:0.25155
# [100]	validation_0-mlogloss:0.25004
# [102]	validation_0-mlogloss:0.24854
# [104]	validation_0-mlogloss:0.24726
# [106]	validation_0-mlogloss:0.24580
# [108]	validation_0-mlogloss:0.24452
# [110]	validation_0-mlogloss:0.24309
# [112]	validation_0-mlogloss:0.24186
# [114]	validation_0-mlogloss:0.24075
# [116]	validation_0-mlogloss:0.23985
# [118]	validation_0-mlogloss:0.23873
# [120]	validation_0-mlogloss:0.23759
# [122]	validation_0-mlogloss:0.23658
# [124]	validation_0-mlogloss:0.23554
# [126]	validation_0-mlogloss:0.23476
# [128]	validation_0-mlogloss:0.23377
# [130]	validation_0-mlogloss:0.23287
# [132]	validation_0-mlogloss:0.23191
# [134]	validation_0-mlogloss:0.23088
# [136]	validation_0-mlogloss:0.22996
# [138]	validation_0-mlogloss:0.22905
# [140]	validation_0-mlogloss:0.22813
# [142]	validation_0-mlogloss:0.22740
# [144]	validation_0-mlogloss:0.22655
# [146]	validation_0-mlogloss:0.22585
# [148]	validation_0-mlogloss:0.22509
# [150]	validation_0-mlogloss:0.22436
# [152]	validation_0-mlogloss:0.22363
# [154]	validation_0-mlogloss:0.22296
# [156]	validation_0-mlogloss:0.22215
# [158]	validation_0-mlogloss:0.22147
# [160]	validation_0-mlogloss:0.22054
# [162]	validation_0-mlogloss:0.21993
# [164]	validation_0-mlogloss:0.21924
# [166]	validation_0-mlogloss:0.21874
# [168]	validation_0-mlogloss:0.21807
# [170]	validation_0-mlogloss:0.21760
# [172]	validation_0-mlogloss:0.21700
# [174]	validation_0-mlogloss:0.21634
# [176]	validation_0-mlogloss:0.21573
# [178]	validation_0-mlogloss:0.21517
# [180]	validation_0-mlogloss:0.21455
# [182]	validation_0-mlogloss:0.21393
# [184]	validation_0-mlogloss:0.21342
# [186]	validation_0-mlogloss:0.21285
# [188]	validation_0-mlogloss:0.21244
# [190]	validation_0-mlogloss:0.21188
# [192]	validation_0-mlogloss:0.21146
# [194]	validation_0-mlogloss:0.21100
# [196]	validation_0-mlogloss:0.21058
# [198]	validation_0-mlogloss:0.21017
# [200]	validation_0-mlogloss:0.20978
# [202]	validation_0-mlogloss:0.20941
# [204]	validation_0-mlogloss:0.20888
# [206]	validation_0-mlogloss:0.20843
# [208]	validation_0-mlogloss:0.20794
# [210]	validation_0-mlogloss:0.20757
# [212]	validation_0-mlogloss:0.20727
# [214]	validation_0-mlogloss:0.20683
# [216]	validation_0-mlogloss:0.20652
# [218]	validation_0-mlogloss:0.20592
# [220]	validation_0-mlogloss:0.20527
# [222]	validation_0-mlogloss:0.20493
# [224]	validation_0-mlogloss:0.20448
# [226]	validation_0-mlogloss:0.20407
# [228]	validation_0-mlogloss:0.20348
# [230]	validation_0-mlogloss:0.20308
# [232]	validation_0-mlogloss:0.20262
# [234]	validation_0-mlogloss:0.20244
# [236]	validation_0-mlogloss:0.20208
# [238]	validation_0-mlogloss:0.20191
# [240]	validation_0-mlogloss:0.20156
# [242]	validation_0-mlogloss:0.20121
# [244]	validation_0-mlogloss:0.20093
# [246]	validation_0-mlogloss:0.20067
# [248]	validation_0-mlogloss:0.20035
# [250]	validation_0-mlogloss:0.20004
# [252]	validation_0-mlogloss:0.19972
# [254]	validation_0-mlogloss:0.19947
# [256]	validation_0-mlogloss:0.19920
# [258]	validation_0-mlogloss:0.19881
# [260]	validation_0-mlogloss:0.19833
# [262]	validation_0-mlogloss:0.19804
# [264]	validation_0-mlogloss:0.19785
# [266]	validation_0-mlogloss:0.19770
# [268]	validation_0-mlogloss:0.19739
# [270]	validation_0-mlogloss:0.19705
# [272]	validation_0-mlogloss:0.19676
# [274]	validation_0-mlogloss:0.19647
# [276]	validation_0-mlogloss:0.19620
# [278]	validation_0-mlogloss:0.19595
# [280]	validation_0-mlogloss:0.19567
# [282]	validation_0-mlogloss:0.19543
# [284]	validation_0-mlogloss:0.19507
# [286]	validation_0-mlogloss:0.19470
# [288]	validation_0-mlogloss:0.19452
# [290]	validation_0-mlogloss:0.19425
# [292]	validation_0-mlogloss:0.19403
# [294]	validation_0-mlogloss:0.19379
# [296]	validation_0-mlogloss:0.19362
# [298]	validation_0-mlogloss:0.19342
# [300]	validation_0-mlogloss:0.19308
# [302]	validation_0-mlogloss:0.19290
# [304]	validation_0-mlogloss:0.19265
# [306]	validation_0-mlogloss:0.19251
# [308]	validation_0-mlogloss:0.19226
# [310]	validation_0-mlogloss:0.19189
# [312]	validation_0-mlogloss:0.19152
# [314]	validation_0-mlogloss:0.19129
# [316]	validation_0-mlogloss:0.19115
# [318]	validation_0-mlogloss:0.19088
# [320]	validation_0-mlogloss:0.19067
# [322]	validation_0-mlogloss:0.19046
# [324]	validation_0-mlogloss:0.19020
# [326]	validation_0-mlogloss:0.19001
# [328]	validation_0-mlogloss:0.18987
# [330]	validation_0-mlogloss:0.18974
# [332]	validation_0-mlogloss:0.18965
# [334]	validation_0-mlogloss:0.18941
# [336]	validation_0-mlogloss:0.18926
# [338]	validation_0-mlogloss:0.18913
# [340]	validation_0-mlogloss:0.18893
# [342]	validation_0-mlogloss:0.18874
# [344]	validation_0-mlogloss:0.18859
# [346]	validation_0-mlogloss:0.18848
# [348]	validation_0-mlogloss:0.18837
# [350]	validation_0-mlogloss:0.18818
# [352]	validation_0-mlogloss:0.18803
# [354]	validation_0-mlogloss:0.18786
# [356]	validation_0-mlogloss:0.18769
# [358]	validation_0-mlogloss:0.18756
# [360]	validation_0-mlogloss:0.18743
# [362]	validation_0-mlogloss:0.18738
# [364]	validation_0-mlogloss:0.18721
# [366]	validation_0-mlogloss:0.18707
# [368]	validation_0-mlogloss:0.18686
# [370]	validation_0-mlogloss:0.18665
# [372]	validation_0-mlogloss:0.18636
# [374]	validation_0-mlogloss:0.18621
# [376]	validation_0-mlogloss:0.18605
# [378]	validation_0-mlogloss:0.18598
# [380]	validation_0-mlogloss:0.18584
# [382]	validation_0-mlogloss:0.18559
# [384]	validation_0-mlogloss:0.18537
# [386]	validation_0-mlogloss:0.18524
# [388]	validation_0-mlogloss:0.18512
# [390]	validation_0-mlogloss:0.18503
# [392]	validation_0-mlogloss:0.18496
# [394]	validation_0-mlogloss:0.18490
# [396]	validation_0-mlogloss:0.18476
# [398]	validation_0-mlogloss:0.18461
# [400]	validation_0-mlogloss:0.18442
# [402]	validation_0-mlogloss:0.18428
# [404]	validation_0-mlogloss:0.18410
# [406]	validation_0-mlogloss:0.18402
# [408]	validation_0-mlogloss:0.18389
# [410]	validation_0-mlogloss:0.18378
# [412]	validation_0-mlogloss:0.18364
# [414]	validation_0-mlogloss:0.18346
# [416]	validation_0-mlogloss:0.18339
# [418]	validation_0-mlogloss:0.18332
# [420]	validation_0-mlogloss:0.18324
# [422]	validation_0-mlogloss:0.18311
# [424]	validation_0-mlogloss:0.18303
# [426]	validation_0-mlogloss:0.18296
# [428]	validation_0-mlogloss:0.18286
# [430]	validation_0-mlogloss:0.18283
# [432]	validation_0-mlogloss:0.18277
# [434]	validation_0-mlogloss:0.18265
# [436]	validation_0-mlogloss:0.18258
# [438]	validation_0-mlogloss:0.18255
# [440]	validation_0-mlogloss:0.18248
# [442]	validation_0-mlogloss:0.18237
# [444]	validation_0-mlogloss:0.18229
# [446]	validation_0-mlogloss:0.18227
# [448]	validation_0-mlogloss:0.18219
# [450]	validation_0-mlogloss:0.18208
# [452]	validation_0-mlogloss:0.18204
# [454]	validation_0-mlogloss:0.18195
# [456]	validation_0-mlogloss:0.18191
# [458]	validation_0-mlogloss:0.18184
# [460]	validation_0-mlogloss:0.18172
# [462]	validation_0-mlogloss:0.18156
# [464]	validation_0-mlogloss:0.18148
# [466]	validation_0-mlogloss:0.18148
# [468]	validation_0-mlogloss:0.18143
# [470]	validation_0-mlogloss:0.18135
# [472]	validation_0-mlogloss:0.18130
# [474]	validation_0-mlogloss:0.18129
# [476]	validation_0-mlogloss:0.18125
# [478]	validation_0-mlogloss:0.18121
# [480]	validation_0-mlogloss:0.18113
# [482]	validation_0-mlogloss:0.18102
# [484]	validation_0-mlogloss:0.18103
# [486]	validation_0-mlogloss:0.18102
# [488]	validation_0-mlogloss:0.18101
# [490]	validation_0-mlogloss:0.18094
# [492]	validation_0-mlogloss:0.18087
# [494]	validation_0-mlogloss:0.18076
# [496]	validation_0-mlogloss:0.18071
# [498]	validation_0-mlogloss:0.18064
# [500]	validation_0-mlogloss:0.18065
# [502]	validation_0-mlogloss:0.18060
# [504]	validation_0-mlogloss:0.18061
# [506]	validation_0-mlogloss:0.18062
# [508]	validation_0-mlogloss:0.18060
# [510]	validation_0-mlogloss:0.18054
# [512]	validation_0-mlogloss:0.18052
# [514]	validation_0-mlogloss:0.18047
# [516]	validation_0-mlogloss:0.18050
# [518]	validation_0-mlogloss:0.18054
# [520]	validation_0-mlogloss:0.18047
# [522]	validation_0-mlogloss:0.18051
# [524]	validation_0-mlogloss:0.18047
# [526]	validation_0-mlogloss:0.18044
# [528]	validation_0-mlogloss:0.18044
# [530]	validation_0-mlogloss:0.18040
# [532]	validation_0-mlogloss:0.18045
# [534]	validation_0-mlogloss:0.18043
# [536]	validation_0-mlogloss:0.18040
# [538]	validation_0-mlogloss:0.18037
# [540]	validation_0-mlogloss:0.18040
# [542]	validation_0-mlogloss:0.18042
# [544]	validation_0-mlogloss:0.18031
# [546]	validation_0-mlogloss:0.18029
# [548]	validation_0-mlogloss:0.18017
# [550]	validation_0-mlogloss:0.18012
# [552]	validation_0-mlogloss:0.18004
# [554]	validation_0-mlogloss:0.17994
# [556]	validation_0-mlogloss:0.17995
# [558]	validation_0-mlogloss:0.17989
# [560]	validation_0-mlogloss:0.17990
# [562]	validation_0-mlogloss:0.17987
# [564]	validation_0-mlogloss:0.17987
# [566]	validation_0-mlogloss:0.17984
# [568]	validation_0-mlogloss:0.17978
# [570]	validation_0-mlogloss:0.17977
# [572]	validation_0-mlogloss:0.17976
# [574]	validation_0-mlogloss:0.17978
# [576]	validation_0-mlogloss:0.17976
# [578]	validation_0-mlogloss:0.17973
# [580]	validation_0-mlogloss:0.17969
# [582]	validation_0-mlogloss:0.17971
# [584]	validation_0-mlogloss:0.17965
# [586]	validation_0-mlogloss:0.17967
# [588]	validation_0-mlogloss:0.17966
# [590]	validation_0-mlogloss:0.17965
# [592]	validation_0-mlogloss:0.17968
# [594]	validation_0-mlogloss:0.17968
# [596]	validation_0-mlogloss:0.17969
# [598]	validation_0-mlogloss:0.17974
# [600]	validation_0-mlogloss:0.17974
# [602]	validation_0-mlogloss:0.17973
# [604]	validation_0-mlogloss:0.17971
# [606]	validation_0-mlogloss:0.17976
# [608]	validation_0-mlogloss:0.17975
# [610]	validation_0-mlogloss:0.17976
# [612]	validation_0-mlogloss:0.17979
# [614]	validation_0-mlogloss:0.17980
# [616]	validation_0-mlogloss:0.17983
# [618]	validation_0-mlogloss:0.17983
# [620]	validation_0-mlogloss:0.17985
# [622]	validation_0-mlogloss:0.17988
# [624]	validation_0-mlogloss:0.17988
# [626]	validation_0-mlogloss:0.17987
# [628]	validation_0-mlogloss:0.17986
# [630]	validation_0-mlogloss:0.17990
# [632]	validation_0-mlogloss:0.17989
# [634]	validation_0-mlogloss:0.18003
# [636]	validation_0-mlogloss:0.18000
# [638]	validation_0-mlogloss:0.18009
# [640]	validation_0-mlogloss:0.18008
# [642]	validation_0-mlogloss:0.18014
# [644]	validation_0-mlogloss:0.18011
# [646]	validation_0-mlogloss:0.18002
# [648]	validation_0-mlogloss:0.17994
# [650]	validation_0-mlogloss:0.17993
# [652]	validation_0-mlogloss:0.17993
# [654]	validation_0-mlogloss:0.17996
# [656]	validation_0-mlogloss:0.18003
# [658]	validation_0-mlogloss:0.18007
# [660]	validation_0-mlogloss:0.18006
# [662]	validation_0-mlogloss:0.18004
# [664]	validation_0-mlogloss:0.18002
# [666]	validation_0-mlogloss:0.18007
# [668]	validation_0-mlogloss:0.18012
# [670]	validation_0-mlogloss:0.18012
# [672]	validation_0-mlogloss:0.18012
# [674]	validation_0-mlogloss:0.18015
# [676]	validation_0-mlogloss:0.18013
# [678]	validation_0-mlogloss:0.18015
# [680]	validation_0-mlogloss:0.18013
# [682]	validation_0-mlogloss:0.18019
# [684]	validation_0-mlogloss:0.18021
# [686]	validation_0-mlogloss:0.18027
# [688]	validation_0-mlogloss:0.18025
# [690]	validation_0-mlogloss:0.18021
# [692]	validation_0-mlogloss:0.18016
# [694]	validation_0-mlogloss:0.18020
# [696]	validation_0-mlogloss:0.18023
# [698]	validation_0-mlogloss:0.18023
# [699]	validation_0-mlogloss:0.18021
# #########################
# ### Fold 2
# ### Train size 96000 Valid size 24000
# #########################
# [0]	validation_0-mlogloss:1.70769
# [2]	validation_0-mlogloss:1.38251
# [4]	validation_0-mlogloss:1.16234
# [6]	validation_0-mlogloss:1.00151
# [8]	validation_0-mlogloss:0.87900
# [10]	validation_0-mlogloss:0.78058
# [12]	validation_0-mlogloss:0.70204
# [14]	validation_0-mlogloss:0.63783
# [16]	validation_0-mlogloss:0.58532
# [18]	validation_0-mlogloss:0.54164
# [20]	validation_0-mlogloss:0.50570
# [22]	validation_0-mlogloss:0.47553
# [24]	validation_0-mlogloss:0.45051
# [26]	validation_0-mlogloss:0.42923
# [28]	validation_0-mlogloss:0.41077
# [30]	validation_0-mlogloss:0.39476
# [32]	validation_0-mlogloss:0.38102
# [34]	validation_0-mlogloss:0.36885
# [36]	validation_0-mlogloss:0.35843
# [38]	validation_0-mlogloss:0.34888
# [40]	validation_0-mlogloss:0.34080
# [42]	validation_0-mlogloss:0.33334
# [44]	validation_0-mlogloss:0.32658
# [46]	validation_0-mlogloss:0.32047
# [48]	validation_0-mlogloss:0.31476
# [50]	validation_0-mlogloss:0.30936
# [52]	validation_0-mlogloss:0.30455
# [54]	validation_0-mlogloss:0.30045
# [56]	validation_0-mlogloss:0.29668
# [58]	validation_0-mlogloss:0.29309
# [60]	validation_0-mlogloss:0.28968
# [62]	validation_0-mlogloss:0.28638
# [64]	validation_0-mlogloss:0.28362
# [66]	validation_0-mlogloss:0.28061
# [68]	validation_0-mlogloss:0.27780
# [70]	validation_0-mlogloss:0.27531
# [72]	validation_0-mlogloss:0.27271
# [74]	validation_0-mlogloss:0.27019
# [76]	validation_0-mlogloss:0.26808
# [78]	validation_0-mlogloss:0.26593
# [80]	validation_0-mlogloss:0.26369
# [82]	validation_0-mlogloss:0.26137
# [84]	validation_0-mlogloss:0.25956
# [86]	validation_0-mlogloss:0.25759
# [88]	validation_0-mlogloss:0.25592
# [90]	validation_0-mlogloss:0.25421
# [92]	validation_0-mlogloss:0.25242
# [94]	validation_0-mlogloss:0.25084
# [96]	validation_0-mlogloss:0.24912
# [98]	validation_0-mlogloss:0.24740
# [100]	validation_0-mlogloss:0.24574
# [102]	validation_0-mlogloss:0.24444
# [104]	validation_0-mlogloss:0.24306
# [106]	validation_0-mlogloss:0.24170
# [108]	validation_0-mlogloss:0.24034
# [110]	validation_0-mlogloss:0.23916
# [112]	validation_0-mlogloss:0.23793
# [114]	validation_0-mlogloss:0.23674
# [116]	validation_0-mlogloss:0.23580
# [118]	validation_0-mlogloss:0.23464
# [120]	validation_0-mlogloss:0.23372
# [122]	validation_0-mlogloss:0.23263
# [124]	validation_0-mlogloss:0.23156
# [126]	validation_0-mlogloss:0.23077
# [128]	validation_0-mlogloss:0.22992
# [130]	validation_0-mlogloss:0.22882
# [132]	validation_0-mlogloss:0.22787
# [134]	validation_0-mlogloss:0.22708
# [136]	validation_0-mlogloss:0.22613
# [138]	validation_0-mlogloss:0.22551
# [140]	validation_0-mlogloss:0.22472
# [142]	validation_0-mlogloss:0.22400
# [144]	validation_0-mlogloss:0.22319
# [146]	validation_0-mlogloss:0.22241
# [148]	validation_0-mlogloss:0.22162
# [150]	validation_0-mlogloss:0.22070
# [152]	validation_0-mlogloss:0.21968
# [154]	validation_0-mlogloss:0.21890
# [156]	validation_0-mlogloss:0.21810
# [158]	validation_0-mlogloss:0.21736
# [160]	validation_0-mlogloss:0.21658
# [162]	validation_0-mlogloss:0.21590
# [164]	validation_0-mlogloss:0.21532
# [166]	validation_0-mlogloss:0.21479
# [168]	validation_0-mlogloss:0.21425
# [170]	validation_0-mlogloss:0.21384
# [172]	validation_0-mlogloss:0.21341
# [174]	validation_0-mlogloss:0.21272
# [176]	validation_0-mlogloss:0.21221
# [178]	validation_0-mlogloss:0.21161
# [180]	validation_0-mlogloss:0.21093
# [182]	validation_0-mlogloss:0.21046
# [184]	validation_0-mlogloss:0.20999
# [186]	validation_0-mlogloss:0.20946
# [188]	validation_0-mlogloss:0.20883
# [190]	validation_0-mlogloss:0.20832
# [192]	validation_0-mlogloss:0.20772
# [194]	validation_0-mlogloss:0.20714
# [196]	validation_0-mlogloss:0.20669
# [198]	validation_0-mlogloss:0.20643
# [200]	validation_0-mlogloss:0.20597
# [202]	validation_0-mlogloss:0.20550
# [204]	validation_0-mlogloss:0.20502
# [206]	validation_0-mlogloss:0.20449
# [208]	validation_0-mlogloss:0.20397
# [210]	validation_0-mlogloss:0.20351
# [212]	validation_0-mlogloss:0.20299
# [214]	validation_0-mlogloss:0.20246
# [216]	validation_0-mlogloss:0.20198
# [218]	validation_0-mlogloss:0.20147
# [220]	validation_0-mlogloss:0.20106
# [222]	validation_0-mlogloss:0.20078
# [224]	validation_0-mlogloss:0.20039
# [226]	validation_0-mlogloss:0.19990
# [228]	validation_0-mlogloss:0.19946
# [230]	validation_0-mlogloss:0.19905
# [232]	validation_0-mlogloss:0.19859
# [234]	validation_0-mlogloss:0.19828
# [236]	validation_0-mlogloss:0.19796
# [238]	validation_0-mlogloss:0.19763
# [240]	validation_0-mlogloss:0.19716
# [242]	validation_0-mlogloss:0.19683
# [244]	validation_0-mlogloss:0.19660
# [246]	validation_0-mlogloss:0.19618
# [248]	validation_0-mlogloss:0.19586
# [250]	validation_0-mlogloss:0.19557
# [252]	validation_0-mlogloss:0.19537
# [254]	validation_0-mlogloss:0.19516
# [256]	validation_0-mlogloss:0.19487
# [258]	validation_0-mlogloss:0.19445
# [260]	validation_0-mlogloss:0.19421
# [262]	validation_0-mlogloss:0.19389
# [264]	validation_0-mlogloss:0.19373
# [266]	validation_0-mlogloss:0.19347
# [268]	validation_0-mlogloss:0.19307
# [270]	validation_0-mlogloss:0.19280
# [272]	validation_0-mlogloss:0.19243
# [274]	validation_0-mlogloss:0.19208
# [276]	validation_0-mlogloss:0.19172
# [278]	validation_0-mlogloss:0.19151
# [280]	validation_0-mlogloss:0.19129
# [282]	validation_0-mlogloss:0.19106
# [284]	validation_0-mlogloss:0.19073
# [286]	validation_0-mlogloss:0.19049
# [288]	validation_0-mlogloss:0.19029
# [290]	validation_0-mlogloss:0.19017
# [292]	validation_0-mlogloss:0.18995
# [294]	validation_0-mlogloss:0.18975
# [296]	validation_0-mlogloss:0.18948
# [298]	validation_0-mlogloss:0.18923
# [300]	validation_0-mlogloss:0.18901
# [302]	validation_0-mlogloss:0.18863
# [304]	validation_0-mlogloss:0.18838
# [306]	validation_0-mlogloss:0.18823
# [308]	validation_0-mlogloss:0.18802
# [310]	validation_0-mlogloss:0.18792
# [312]	validation_0-mlogloss:0.18768
# [314]	validation_0-mlogloss:0.18745
# [316]	validation_0-mlogloss:0.18719
# [318]	validation_0-mlogloss:0.18692
# [320]	validation_0-mlogloss:0.18667
# [322]	validation_0-mlogloss:0.18646
# [324]	validation_0-mlogloss:0.18625
# [326]	validation_0-mlogloss:0.18607
# [328]	validation_0-mlogloss:0.18590
# [330]	validation_0-mlogloss:0.18574
# [332]	validation_0-mlogloss:0.18560
# [334]	validation_0-mlogloss:0.18534
# [336]	validation_0-mlogloss:0.18516
# [338]	validation_0-mlogloss:0.18504
# [340]	validation_0-mlogloss:0.18485
# [342]	validation_0-mlogloss:0.18460
# [344]	validation_0-mlogloss:0.18441
# [346]	validation_0-mlogloss:0.18420
# [348]	validation_0-mlogloss:0.18405
# [350]	validation_0-mlogloss:0.18395
# [352]	validation_0-mlogloss:0.18372
# [354]	validation_0-mlogloss:0.18364
# [356]	validation_0-mlogloss:0.18347
# [358]	validation_0-mlogloss:0.18329
# [360]	validation_0-mlogloss:0.18318
# [362]	validation_0-mlogloss:0.18304
# [364]	validation_0-mlogloss:0.18281
# [366]	validation_0-mlogloss:0.18271
# [368]	validation_0-mlogloss:0.18257
# [370]	validation_0-mlogloss:0.18235
# [372]	validation_0-mlogloss:0.18218
# [374]	validation_0-mlogloss:0.18212
# [376]	validation_0-mlogloss:0.18194
# [378]	validation_0-mlogloss:0.18180
# [380]	validation_0-mlogloss:0.18167
# [382]	validation_0-mlogloss:0.18149
# [384]	validation_0-mlogloss:0.18129
# [386]	validation_0-mlogloss:0.18119
# [388]	validation_0-mlogloss:0.18106
# [390]	validation_0-mlogloss:0.18097
# [392]	validation_0-mlogloss:0.18095
# [394]	validation_0-mlogloss:0.18084
# [396]	validation_0-mlogloss:0.18087
# [398]	validation_0-mlogloss:0.18077
# [400]	validation_0-mlogloss:0.18071
# [402]	validation_0-mlogloss:0.18051
# [404]	validation_0-mlogloss:0.18033
# [406]	validation_0-mlogloss:0.18017
# [408]	validation_0-mlogloss:0.18012
# [410]	validation_0-mlogloss:0.18003
# [412]	validation_0-mlogloss:0.17994
# [414]	validation_0-mlogloss:0.17980
# [416]	validation_0-mlogloss:0.17970
# [418]	validation_0-mlogloss:0.17961
# [420]	validation_0-mlogloss:0.17961
# [422]	validation_0-mlogloss:0.17956
# [424]	validation_0-mlogloss:0.17951
# [426]	validation_0-mlogloss:0.17944
# [428]	validation_0-mlogloss:0.17936
# [430]	validation_0-mlogloss:0.17930
# [432]	validation_0-mlogloss:0.17928
# [434]	validation_0-mlogloss:0.17920
# [436]	validation_0-mlogloss:0.17909
# [438]	validation_0-mlogloss:0.17901
# [440]	validation_0-mlogloss:0.17898
# [442]	validation_0-mlogloss:0.17896
# [444]	validation_0-mlogloss:0.17881
# [446]	validation_0-mlogloss:0.17876
# [448]	validation_0-mlogloss:0.17860
# [450]	validation_0-mlogloss:0.17847
# [452]	validation_0-mlogloss:0.17830
# [454]	validation_0-mlogloss:0.17829
# [456]	validation_0-mlogloss:0.17822
# [458]	validation_0-mlogloss:0.17807
# [460]	validation_0-mlogloss:0.17795
# [462]	validation_0-mlogloss:0.17792
# [464]	validation_0-mlogloss:0.17783
# [466]	validation_0-mlogloss:0.17771
# [468]	validation_0-mlogloss:0.17755
# [470]	validation_0-mlogloss:0.17744
# [472]	validation_0-mlogloss:0.17737
# [474]	validation_0-mlogloss:0.17720
# [476]	validation_0-mlogloss:0.17710
# [478]	validation_0-mlogloss:0.17706
# [480]	validation_0-mlogloss:0.17707
# [482]	validation_0-mlogloss:0.17705
# [484]	validation_0-mlogloss:0.17695
# [486]	validation_0-mlogloss:0.17699
# [488]	validation_0-mlogloss:0.17696
# [490]	validation_0-mlogloss:0.17686
# [492]	validation_0-mlogloss:0.17683
# [494]	validation_0-mlogloss:0.17682
# [496]	validation_0-mlogloss:0.17672
# [498]	validation_0-mlogloss:0.17669
# [500]	validation_0-mlogloss:0.17669
# [502]	validation_0-mlogloss:0.17669
# [504]	validation_0-mlogloss:0.17667
# [506]	validation_0-mlogloss:0.17662
# [508]	validation_0-mlogloss:0.17663
# [510]	validation_0-mlogloss:0.17661
# [512]	validation_0-mlogloss:0.17652
# [514]	validation_0-mlogloss:0.17647
# [516]	validation_0-mlogloss:0.17642
# [518]	validation_0-mlogloss:0.17642
# [520]	validation_0-mlogloss:0.17643
# [522]	validation_0-mlogloss:0.17638
# [524]	validation_0-mlogloss:0.17644
# [526]	validation_0-mlogloss:0.17643
# [528]	validation_0-mlogloss:0.17639
# [530]	validation_0-mlogloss:0.17638
# [532]	validation_0-mlogloss:0.17629
# [534]	validation_0-mlogloss:0.17625
# [536]	validation_0-mlogloss:0.17617
# [538]	validation_0-mlogloss:0.17608
# [540]	validation_0-mlogloss:0.17603
# [542]	validation_0-mlogloss:0.17601
# [544]	validation_0-mlogloss:0.17602
# [546]	validation_0-mlogloss:0.17606
# [548]	validation_0-mlogloss:0.17604
# [550]	validation_0-mlogloss:0.17606
# [552]	validation_0-mlogloss:0.17600
# [554]	validation_0-mlogloss:0.17593
# [556]	validation_0-mlogloss:0.17590
# [558]	validation_0-mlogloss:0.17585
# [560]	validation_0-mlogloss:0.17585
# [562]	validation_0-mlogloss:0.17586
# [564]	validation_0-mlogloss:0.17580
# [566]	validation_0-mlogloss:0.17577
# [568]	validation_0-mlogloss:0.17574
# [570]	validation_0-mlogloss:0.17569
# [572]	validation_0-mlogloss:0.17569
# [574]	validation_0-mlogloss:0.17566
# [576]	validation_0-mlogloss:0.17570
# [578]	validation_0-mlogloss:0.17564
# [580]	validation_0-mlogloss:0.17566
# [582]	validation_0-mlogloss:0.17571
# [584]	validation_0-mlogloss:0.17574
# [586]	validation_0-mlogloss:0.17566
# [588]	validation_0-mlogloss:0.17564
# [590]	validation_0-mlogloss:0.17566
# [592]	validation_0-mlogloss:0.17561
# [594]	validation_0-mlogloss:0.17558
# [596]	validation_0-mlogloss:0.17561
# [598]	validation_0-mlogloss:0.17557
# [600]	validation_0-mlogloss:0.17560
# [602]	validation_0-mlogloss:0.17564
# [604]	validation_0-mlogloss:0.17561
# [606]	validation_0-mlogloss:0.17554
# [608]	validation_0-mlogloss:0.17552
# [610]	validation_0-mlogloss:0.17556
# [612]	validation_0-mlogloss:0.17562
# [614]	validation_0-mlogloss:0.17557
# [616]	validation_0-mlogloss:0.17557
# [618]	validation_0-mlogloss:0.17552
# [620]	validation_0-mlogloss:0.17551
# [622]	validation_0-mlogloss:0.17549
# [624]	validation_0-mlogloss:0.17545
# [626]	validation_0-mlogloss:0.17543
# [628]	validation_0-mlogloss:0.17537
# [630]	validation_0-mlogloss:0.17540
# [632]	validation_0-mlogloss:0.17538
# [634]	validation_0-mlogloss:0.17539
# [636]	validation_0-mlogloss:0.17542
# [638]	validation_0-mlogloss:0.17538
# [640]	validation_0-mlogloss:0.17534
# [642]	validation_0-mlogloss:0.17530
# [644]	validation_0-mlogloss:0.17531
# [646]	validation_0-mlogloss:0.17530
# [648]	validation_0-mlogloss:0.17534
# [650]	validation_0-mlogloss:0.17538
# [652]	validation_0-mlogloss:0.17536
# [654]	validation_0-mlogloss:0.17538
# [656]	validation_0-mlogloss:0.17536
# [658]	validation_0-mlogloss:0.17530
# [660]	validation_0-mlogloss:0.17533
# [662]	validation_0-mlogloss:0.17537
# [664]	validation_0-mlogloss:0.17539
# [666]	validation_0-mlogloss:0.17538
# [668]	validation_0-mlogloss:0.17543
# [670]	validation_0-mlogloss:0.17539
# [672]	validation_0-mlogloss:0.17538
# [674]	validation_0-mlogloss:0.17536
# [676]	validation_0-mlogloss:0.17542
# [678]	validation_0-mlogloss:0.17542
# [680]	validation_0-mlogloss:0.17543
# [682]	validation_0-mlogloss:0.17534
# [684]	validation_0-mlogloss:0.17536
# [686]	validation_0-mlogloss:0.17544
# [688]	validation_0-mlogloss:0.17541
# [690]	validation_0-mlogloss:0.17536
# [692]	validation_0-mlogloss:0.17536
# [694]	validation_0-mlogloss:0.17535
# [696]	validation_0-mlogloss:0.17535
# [698]	validation_0-mlogloss:0.17540
# [699]	validation_0-mlogloss:0.17543
# #########################
# ### Fold 3
# ### Train size 96000 Valid size 24000
# #########################
# [0]	validation_0-mlogloss:1.70723
# [2]	validation_0-mlogloss:1.38446
# [4]	validation_0-mlogloss:1.16435
# [6]	validation_0-mlogloss:1.00331
# [8]	validation_0-mlogloss:0.88127
# [10]	validation_0-mlogloss:0.78354
# [12]	validation_0-mlogloss:0.70526
# [14]	validation_0-mlogloss:0.64131
# [16]	validation_0-mlogloss:0.58904
# [18]	validation_0-mlogloss:0.54593
# [20]	validation_0-mlogloss:0.51034
# [22]	validation_0-mlogloss:0.48008
# [24]	validation_0-mlogloss:0.45553
# [26]	validation_0-mlogloss:0.43422
# [28]	validation_0-mlogloss:0.41626
# [30]	validation_0-mlogloss:0.40038
# [32]	validation_0-mlogloss:0.38665
# [34]	validation_0-mlogloss:0.37440
# [36]	validation_0-mlogloss:0.36434
# [38]	validation_0-mlogloss:0.35488
# [40]	validation_0-mlogloss:0.34666
# [42]	validation_0-mlogloss:0.33915
# [44]	validation_0-mlogloss:0.33247
# [46]	validation_0-mlogloss:0.32634
# [48]	validation_0-mlogloss:0.32075
# [50]	validation_0-mlogloss:0.31570
# [52]	validation_0-mlogloss:0.31107
# [54]	validation_0-mlogloss:0.30658
# [56]	validation_0-mlogloss:0.30252
# [58]	validation_0-mlogloss:0.29864
# [60]	validation_0-mlogloss:0.29514
# [62]	validation_0-mlogloss:0.29180
# [64]	validation_0-mlogloss:0.28854
# [66]	validation_0-mlogloss:0.28553
# [68]	validation_0-mlogloss:0.28240
# [70]	validation_0-mlogloss:0.27959
# [72]	validation_0-mlogloss:0.27699
# [74]	validation_0-mlogloss:0.27457
# [76]	validation_0-mlogloss:0.27231
# [78]	validation_0-mlogloss:0.26976
# [80]	validation_0-mlogloss:0.26759
# [82]	validation_0-mlogloss:0.26546
# [84]	validation_0-mlogloss:0.26343
# [86]	validation_0-mlogloss:0.26154
# [88]	validation_0-mlogloss:0.25990
# [90]	validation_0-mlogloss:0.25808
# [92]	validation_0-mlogloss:0.25640
# [94]	validation_0-mlogloss:0.25472
# [96]	validation_0-mlogloss:0.25306
# [98]	validation_0-mlogloss:0.25111
# [100]	validation_0-mlogloss:0.24944
# [102]	validation_0-mlogloss:0.24806
# [104]	validation_0-mlogloss:0.24665
# [106]	validation_0-mlogloss:0.24516
# [108]	validation_0-mlogloss:0.24372
# [110]	validation_0-mlogloss:0.24251
# [112]	validation_0-mlogloss:0.24135
# [114]	validation_0-mlogloss:0.24028
# [116]	validation_0-mlogloss:0.23924
# [118]	validation_0-mlogloss:0.23798
# [120]	validation_0-mlogloss:0.23685
# [122]	validation_0-mlogloss:0.23570
# [124]	validation_0-mlogloss:0.23455
# [126]	validation_0-mlogloss:0.23346
# [128]	validation_0-mlogloss:0.23228
# [130]	validation_0-mlogloss:0.23120
# [132]	validation_0-mlogloss:0.23025
# [134]	validation_0-mlogloss:0.22940
# [136]	validation_0-mlogloss:0.22851
# [138]	validation_0-mlogloss:0.22753
# [140]	validation_0-mlogloss:0.22664
# [142]	validation_0-mlogloss:0.22563
# [144]	validation_0-mlogloss:0.22482
# [146]	validation_0-mlogloss:0.22392
# [148]	validation_0-mlogloss:0.22308
# [150]	validation_0-mlogloss:0.22230
# [152]	validation_0-mlogloss:0.22160
# [154]	validation_0-mlogloss:0.22070
# [156]	validation_0-mlogloss:0.21997
# [158]	validation_0-mlogloss:0.21917
# [160]	validation_0-mlogloss:0.21846
# [162]	validation_0-mlogloss:0.21770
# [164]	validation_0-mlogloss:0.21710
# [166]	validation_0-mlogloss:0.21638
# [168]	validation_0-mlogloss:0.21575
# [170]	validation_0-mlogloss:0.21511
# [172]	validation_0-mlogloss:0.21454
# [174]	validation_0-mlogloss:0.21377
# [176]	validation_0-mlogloss:0.21321
# [178]	validation_0-mlogloss:0.21267
# [180]	validation_0-mlogloss:0.21202
# [182]	validation_0-mlogloss:0.21130
# [184]	validation_0-mlogloss:0.21072
# [186]	validation_0-mlogloss:0.21015
# [188]	validation_0-mlogloss:0.20980
# [190]	validation_0-mlogloss:0.20933
# [192]	validation_0-mlogloss:0.20872
# [194]	validation_0-mlogloss:0.20826
# [196]	validation_0-mlogloss:0.20795
# [198]	validation_0-mlogloss:0.20746
# [200]	validation_0-mlogloss:0.20692
# [202]	validation_0-mlogloss:0.20646
# [204]	validation_0-mlogloss:0.20598
# [206]	validation_0-mlogloss:0.20549
# [208]	validation_0-mlogloss:0.20499
# [210]	validation_0-mlogloss:0.20455
# [212]	validation_0-mlogloss:0.20413
# [214]	validation_0-mlogloss:0.20368
# [216]	validation_0-mlogloss:0.20321
# [218]	validation_0-mlogloss:0.20290
# [220]	validation_0-mlogloss:0.20249
# [222]	validation_0-mlogloss:0.20205
# [224]	validation_0-mlogloss:0.20169
# [226]	validation_0-mlogloss:0.20125
# [228]	validation_0-mlogloss:0.20085
# [230]	validation_0-mlogloss:0.20055
# [232]	validation_0-mlogloss:0.20019
# [234]	validation_0-mlogloss:0.19997
# [236]	validation_0-mlogloss:0.19960
# [238]	validation_0-mlogloss:0.19916
# [240]	validation_0-mlogloss:0.19875
# [242]	validation_0-mlogloss:0.19846
# [244]	validation_0-mlogloss:0.19824
# [246]	validation_0-mlogloss:0.19799
# [248]	validation_0-mlogloss:0.19772
# [250]	validation_0-mlogloss:0.19733
# [252]	validation_0-mlogloss:0.19696
# [254]	validation_0-mlogloss:0.19663
# [256]	validation_0-mlogloss:0.19619
# [258]	validation_0-mlogloss:0.19583
# [260]	validation_0-mlogloss:0.19557
# [262]	validation_0-mlogloss:0.19526
# [264]	validation_0-mlogloss:0.19505
# [266]	validation_0-mlogloss:0.19482
# [268]	validation_0-mlogloss:0.19442
# [270]	validation_0-mlogloss:0.19412
# [272]	validation_0-mlogloss:0.19373
# [274]	validation_0-mlogloss:0.19344
# [276]	validation_0-mlogloss:0.19322
# [278]	validation_0-mlogloss:0.19298
# [280]	validation_0-mlogloss:0.19272
# [282]	validation_0-mlogloss:0.19228
# [284]	validation_0-mlogloss:0.19219
# [286]	validation_0-mlogloss:0.19195
# [288]	validation_0-mlogloss:0.19179
# [290]	validation_0-mlogloss:0.19143
# [292]	validation_0-mlogloss:0.19127
# [294]	validation_0-mlogloss:0.19108
# [296]	validation_0-mlogloss:0.19085
# [298]	validation_0-mlogloss:0.19052
# [300]	validation_0-mlogloss:0.19030
# [302]	validation_0-mlogloss:0.19015
# [304]	validation_0-mlogloss:0.18985
# [306]	validation_0-mlogloss:0.18963
# [308]	validation_0-mlogloss:0.18938
# [310]	validation_0-mlogloss:0.18916
# [312]	validation_0-mlogloss:0.18894
# [314]	validation_0-mlogloss:0.18872
# [316]	validation_0-mlogloss:0.18843
# [318]	validation_0-mlogloss:0.18821
# [320]	validation_0-mlogloss:0.18810
# [322]	validation_0-mlogloss:0.18789
# [324]	validation_0-mlogloss:0.18778
# [326]	validation_0-mlogloss:0.18760
# [328]	validation_0-mlogloss:0.18743
# [330]	validation_0-mlogloss:0.18712
# [332]	validation_0-mlogloss:0.18698
# [334]	validation_0-mlogloss:0.18667
# [336]	validation_0-mlogloss:0.18642
# [338]	validation_0-mlogloss:0.18631
# [340]	validation_0-mlogloss:0.18610
# [342]	validation_0-mlogloss:0.18603
# [344]	validation_0-mlogloss:0.18590
# [346]	validation_0-mlogloss:0.18566
# [348]	validation_0-mlogloss:0.18548
# [350]	validation_0-mlogloss:0.18539
# [352]	validation_0-mlogloss:0.18531
# [354]	validation_0-mlogloss:0.18516
# [356]	validation_0-mlogloss:0.18507
# [358]	validation_0-mlogloss:0.18492
# [360]	validation_0-mlogloss:0.18470
# [362]	validation_0-mlogloss:0.18457
# [364]	validation_0-mlogloss:0.18444
# [366]	validation_0-mlogloss:0.18426
# [368]	validation_0-mlogloss:0.18408
# [370]	validation_0-mlogloss:0.18398
# [372]	validation_0-mlogloss:0.18389
# [374]	validation_0-mlogloss:0.18387
# [376]	validation_0-mlogloss:0.18369
# [378]	validation_0-mlogloss:0.18358
# [380]	validation_0-mlogloss:0.18340
# [382]	validation_0-mlogloss:0.18327
# [384]	validation_0-mlogloss:0.18313
# [386]	validation_0-mlogloss:0.18304
# [388]	validation_0-mlogloss:0.18297
# [390]	validation_0-mlogloss:0.18290
# [392]	validation_0-mlogloss:0.18278
# [394]	validation_0-mlogloss:0.18269
# [396]	validation_0-mlogloss:0.18241
# [398]	validation_0-mlogloss:0.18230
# [400]	validation_0-mlogloss:0.18210
# [402]	validation_0-mlogloss:0.18209
# [404]	validation_0-mlogloss:0.18189
# [406]	validation_0-mlogloss:0.18182
# [408]	validation_0-mlogloss:0.18169
# [410]	validation_0-mlogloss:0.18157
# [412]	validation_0-mlogloss:0.18149
# [414]	validation_0-mlogloss:0.18137
# [416]	validation_0-mlogloss:0.18129
# [418]	validation_0-mlogloss:0.18122
# [420]	validation_0-mlogloss:0.18113
# [422]	validation_0-mlogloss:0.18106
# [424]	validation_0-mlogloss:0.18103
# [426]	validation_0-mlogloss:0.18094
# [428]	validation_0-mlogloss:0.18083
# [430]	validation_0-mlogloss:0.18071
# [432]	validation_0-mlogloss:0.18060
# [434]	validation_0-mlogloss:0.18050
# [436]	validation_0-mlogloss:0.18035
# [438]	validation_0-mlogloss:0.18024
# [440]	validation_0-mlogloss:0.18014
# [442]	validation_0-mlogloss:0.18008
# [444]	validation_0-mlogloss:0.18004
# [446]	validation_0-mlogloss:0.17995
# [448]	validation_0-mlogloss:0.17978
# [450]	validation_0-mlogloss:0.17960
# [452]	validation_0-mlogloss:0.17954
# [454]	validation_0-mlogloss:0.17938
# [456]	validation_0-mlogloss:0.17926
# [458]	validation_0-mlogloss:0.17920
# [460]	validation_0-mlogloss:0.17906
# [462]	validation_0-mlogloss:0.17902
# [464]	validation_0-mlogloss:0.17895
# [466]	validation_0-mlogloss:0.17891
# [468]	validation_0-mlogloss:0.17888
# [470]	validation_0-mlogloss:0.17885
# [472]	validation_0-mlogloss:0.17881
# [474]	validation_0-mlogloss:0.17877
# [476]	validation_0-mlogloss:0.17874
# [478]	validation_0-mlogloss:0.17870
# [480]	validation_0-mlogloss:0.17863
# [482]	validation_0-mlogloss:0.17855
# [484]	validation_0-mlogloss:0.17849
# [486]	validation_0-mlogloss:0.17840
# [488]	validation_0-mlogloss:0.17837
# [490]	validation_0-mlogloss:0.17826
# [492]	validation_0-mlogloss:0.17813
# [494]	validation_0-mlogloss:0.17808
# [496]	validation_0-mlogloss:0.17800
# [498]	validation_0-mlogloss:0.17793
# [500]	validation_0-mlogloss:0.17790
# [502]	validation_0-mlogloss:0.17779
# [504]	validation_0-mlogloss:0.17771
# [506]	validation_0-mlogloss:0.17765
# [508]	validation_0-mlogloss:0.17764
# [510]	validation_0-mlogloss:0.17763
# [512]	validation_0-mlogloss:0.17760
# [514]	validation_0-mlogloss:0.17754
# [516]	validation_0-mlogloss:0.17748
# [518]	validation_0-mlogloss:0.17735
# [520]	validation_0-mlogloss:0.17730
# [522]	validation_0-mlogloss:0.17736
# [524]	validation_0-mlogloss:0.17727
# [526]	validation_0-mlogloss:0.17730
# [528]	validation_0-mlogloss:0.17727
# [530]	validation_0-mlogloss:0.17724
# [532]	validation_0-mlogloss:0.17718
# [534]	validation_0-mlogloss:0.17717
# [536]	validation_0-mlogloss:0.17711
# [538]	validation_0-mlogloss:0.17707
# [540]	validation_0-mlogloss:0.17709
# [542]	validation_0-mlogloss:0.17701
# [544]	validation_0-mlogloss:0.17699
# [546]	validation_0-mlogloss:0.17692
# [548]	validation_0-mlogloss:0.17685
# [550]	validation_0-mlogloss:0.17680
# [552]	validation_0-mlogloss:0.17670
# [554]	validation_0-mlogloss:0.17662
# [556]	validation_0-mlogloss:0.17660
# [558]	validation_0-mlogloss:0.17656
# [560]	validation_0-mlogloss:0.17649
# [562]	validation_0-mlogloss:0.17645
# [564]	validation_0-mlogloss:0.17648
# [566]	validation_0-mlogloss:0.17643
# [568]	validation_0-mlogloss:0.17644
# [570]	validation_0-mlogloss:0.17637
# [572]	validation_0-mlogloss:0.17633
# [574]	validation_0-mlogloss:0.17626
# [576]	validation_0-mlogloss:0.17627
# [578]	validation_0-mlogloss:0.17631
# [580]	validation_0-mlogloss:0.17626
# [582]	validation_0-mlogloss:0.17623
# [584]	validation_0-mlogloss:0.17618
# [586]	validation_0-mlogloss:0.17618
# [588]	validation_0-mlogloss:0.17612
# [590]	validation_0-mlogloss:0.17608
# [592]	validation_0-mlogloss:0.17602
# [594]	validation_0-mlogloss:0.17603
# [596]	validation_0-mlogloss:0.17598
# [598]	validation_0-mlogloss:0.17595
# [600]	validation_0-mlogloss:0.17592
# [602]	validation_0-mlogloss:0.17594
# [604]	validation_0-mlogloss:0.17595
# [606]	validation_0-mlogloss:0.17592
# [608]	validation_0-mlogloss:0.17596
# [610]	validation_0-mlogloss:0.17594
# [612]	validation_0-mlogloss:0.17586
# [614]	validation_0-mlogloss:0.17588
# [616]	validation_0-mlogloss:0.17592
# [618]	validation_0-mlogloss:0.17601
# [620]	validation_0-mlogloss:0.17607
# [622]	validation_0-mlogloss:0.17614
# [624]	validation_0-mlogloss:0.17616
# [626]	validation_0-mlogloss:0.17620
# [628]	validation_0-mlogloss:0.17623
# [630]	validation_0-mlogloss:0.17623
# [632]	validation_0-mlogloss:0.17624
# [634]	validation_0-mlogloss:0.17626
# [636]	validation_0-mlogloss:0.17632
# [638]	validation_0-mlogloss:0.17627
# [640]	validation_0-mlogloss:0.17625
# [642]	validation_0-mlogloss:0.17626
# [644]	validation_0-mlogloss:0.17625
# [646]	validation_0-mlogloss:0.17621
# [648]	validation_0-mlogloss:0.17621
# [650]	validation_0-mlogloss:0.17620
# [652]	validation_0-mlogloss:0.17622
# [654]	validation_0-mlogloss:0.17617
# [656]	validation_0-mlogloss:0.17616
# [658]	validation_0-mlogloss:0.17623
# [660]	validation_0-mlogloss:0.17626
# [662]	validation_0-mlogloss:0.17630
# [664]	validation_0-mlogloss:0.17629
# [666]	validation_0-mlogloss:0.17637
# [668]	validation_0-mlogloss:0.17636
# [670]	validation_0-mlogloss:0.17642
# [672]	validation_0-mlogloss:0.17639
# [674]	validation_0-mlogloss:0.17640
# [676]	validation_0-mlogloss:0.17642
# [678]	validation_0-mlogloss:0.17645
# [680]	validation_0-mlogloss:0.17642
# [682]	validation_0-mlogloss:0.17646
# [684]	validation_0-mlogloss:0.17643
# [686]	validation_0-mlogloss:0.17644
# [688]	validation_0-mlogloss:0.17653
# [690]	validation_0-mlogloss:0.17658
# [692]	validation_0-mlogloss:0.17663
# [694]	validation_0-mlogloss:0.17666
# [696]	validation_0-mlogloss:0.17665
# [698]	validation_0-mlogloss:0.17668
# [699]	validation_0-mlogloss:0.17668
# #########################
# ### Fold 4
# ### Train size 96000 Valid size 24000
# #########################
# [0]	validation_0-mlogloss:1.70735
# [2]	validation_0-mlogloss:1.38444
# [4]	validation_0-mlogloss:1.16421
# [6]	validation_0-mlogloss:1.00314
# [8]	validation_0-mlogloss:0.88082
# [10]	validation_0-mlogloss:0.78262
# [12]	validation_0-mlogloss:0.70392
# [14]	validation_0-mlogloss:0.63979
# [16]	validation_0-mlogloss:0.58731
# [18]	validation_0-mlogloss:0.54404
# [20]	validation_0-mlogloss:0.50817
# [22]	validation_0-mlogloss:0.47783
# [24]	validation_0-mlogloss:0.45255
# [26]	validation_0-mlogloss:0.43086
# [28]	validation_0-mlogloss:0.41255
# [30]	validation_0-mlogloss:0.39626
# [32]	validation_0-mlogloss:0.38227
# [34]	validation_0-mlogloss:0.37011
# [36]	validation_0-mlogloss:0.35960
# [38]	validation_0-mlogloss:0.35005
# [40]	validation_0-mlogloss:0.34168
# [42]	validation_0-mlogloss:0.33383
# [44]	validation_0-mlogloss:0.32726
# [46]	validation_0-mlogloss:0.32088
# [48]	validation_0-mlogloss:0.31527
# [50]	validation_0-mlogloss:0.31010
# [52]	validation_0-mlogloss:0.30548
# [54]	validation_0-mlogloss:0.30122
# [56]	validation_0-mlogloss:0.29701
# [58]	validation_0-mlogloss:0.29309
# [60]	validation_0-mlogloss:0.28947
# [62]	validation_0-mlogloss:0.28632
# [64]	validation_0-mlogloss:0.28325
# [66]	validation_0-mlogloss:0.27994
# [68]	validation_0-mlogloss:0.27712
# [70]	validation_0-mlogloss:0.27435
# [72]	validation_0-mlogloss:0.27177
# [74]	validation_0-mlogloss:0.26942
# [76]	validation_0-mlogloss:0.26699
# [78]	validation_0-mlogloss:0.26472
# [80]	validation_0-mlogloss:0.26271
# [82]	validation_0-mlogloss:0.26062
# [84]	validation_0-mlogloss:0.25852
# [86]	validation_0-mlogloss:0.25668
# [88]	validation_0-mlogloss:0.25476
# [90]	validation_0-mlogloss:0.25301
# [92]	validation_0-mlogloss:0.25143
# [94]	validation_0-mlogloss:0.24971
# [96]	validation_0-mlogloss:0.24818
# [98]	validation_0-mlogloss:0.24656
# [100]	validation_0-mlogloss:0.24509
# [102]	validation_0-mlogloss:0.24382
# [104]	validation_0-mlogloss:0.24254
# [106]	validation_0-mlogloss:0.24123
# [108]	validation_0-mlogloss:0.23982
# [110]	validation_0-mlogloss:0.23867
# [112]	validation_0-mlogloss:0.23721
# [114]	validation_0-mlogloss:0.23604
# [116]	validation_0-mlogloss:0.23492
# [118]	validation_0-mlogloss:0.23363
# [120]	validation_0-mlogloss:0.23231
# [122]	validation_0-mlogloss:0.23134
# [124]	validation_0-mlogloss:0.23037
# [126]	validation_0-mlogloss:0.22947
# [128]	validation_0-mlogloss:0.22872
# [130]	validation_0-mlogloss:0.22789
# [132]	validation_0-mlogloss:0.22698
# [134]	validation_0-mlogloss:0.22592
# [136]	validation_0-mlogloss:0.22485
# [138]	validation_0-mlogloss:0.22398
# [140]	validation_0-mlogloss:0.22320
# [142]	validation_0-mlogloss:0.22236
# [144]	validation_0-mlogloss:0.22162
# [146]	validation_0-mlogloss:0.22061
# [148]	validation_0-mlogloss:0.21999
# [150]	validation_0-mlogloss:0.21923
# [152]	validation_0-mlogloss:0.21849
# [154]	validation_0-mlogloss:0.21781
# [156]	validation_0-mlogloss:0.21719
# [158]	validation_0-mlogloss:0.21664
# [160]	validation_0-mlogloss:0.21604
# [162]	validation_0-mlogloss:0.21531
# [164]	validation_0-mlogloss:0.21464
# [166]	validation_0-mlogloss:0.21389
# [168]	validation_0-mlogloss:0.21315
# [170]	validation_0-mlogloss:0.21256
# [172]	validation_0-mlogloss:0.21187
# [174]	validation_0-mlogloss:0.21101
# [176]	validation_0-mlogloss:0.21044
# [178]	validation_0-mlogloss:0.20972
# [180]	validation_0-mlogloss:0.20921
# [182]	validation_0-mlogloss:0.20863
# [184]	validation_0-mlogloss:0.20816
# [186]	validation_0-mlogloss:0.20767
# [188]	validation_0-mlogloss:0.20717
# [190]	validation_0-mlogloss:0.20661
# [192]	validation_0-mlogloss:0.20612
# [194]	validation_0-mlogloss:0.20564
# [196]	validation_0-mlogloss:0.20517
# [198]	validation_0-mlogloss:0.20468
# [200]	validation_0-mlogloss:0.20431
# [202]	validation_0-mlogloss:0.20393
# [204]	validation_0-mlogloss:0.20350
# [206]	validation_0-mlogloss:0.20325
# [208]	validation_0-mlogloss:0.20284
# [210]	validation_0-mlogloss:0.20246
# [212]	validation_0-mlogloss:0.20195
# [214]	validation_0-mlogloss:0.20146
# [216]	validation_0-mlogloss:0.20091
# [218]	validation_0-mlogloss:0.20054
# [220]	validation_0-mlogloss:0.19999
# [222]	validation_0-mlogloss:0.19966
# [224]	validation_0-mlogloss:0.19931
# [226]	validation_0-mlogloss:0.19874
# [228]	validation_0-mlogloss:0.19835
# [230]	validation_0-mlogloss:0.19796
# [232]	validation_0-mlogloss:0.19760
# [234]	validation_0-mlogloss:0.19739
# [236]	validation_0-mlogloss:0.19709
# [238]	validation_0-mlogloss:0.19676
# [240]	validation_0-mlogloss:0.19642
# [242]	validation_0-mlogloss:0.19608
# [244]	validation_0-mlogloss:0.19584
# [246]	validation_0-mlogloss:0.19548
# [248]	validation_0-mlogloss:0.19520
# [250]	validation_0-mlogloss:0.19487
# [252]	validation_0-mlogloss:0.19453
# [254]	validation_0-mlogloss:0.19412
# [256]	validation_0-mlogloss:0.19388
# [258]	validation_0-mlogloss:0.19348
# [260]	validation_0-mlogloss:0.19318
# [262]	validation_0-mlogloss:0.19268
# [264]	validation_0-mlogloss:0.19239
# [266]	validation_0-mlogloss:0.19225
# [268]	validation_0-mlogloss:0.19204
# [270]	validation_0-mlogloss:0.19183
# [272]	validation_0-mlogloss:0.19158
# [274]	validation_0-mlogloss:0.19136
# [276]	validation_0-mlogloss:0.19117
# [278]	validation_0-mlogloss:0.19091
# [280]	validation_0-mlogloss:0.19064
# [282]	validation_0-mlogloss:0.19038
# [284]	validation_0-mlogloss:0.19012
# [286]	validation_0-mlogloss:0.18992
# [288]	validation_0-mlogloss:0.18952
# [290]	validation_0-mlogloss:0.18922
# [292]	validation_0-mlogloss:0.18905
# [294]	validation_0-mlogloss:0.18878
# [296]	validation_0-mlogloss:0.18857
# [298]	validation_0-mlogloss:0.18831
# [300]	validation_0-mlogloss:0.18811
# [302]	validation_0-mlogloss:0.18784
# [304]	validation_0-mlogloss:0.18750
# [306]	validation_0-mlogloss:0.18729
# [308]	validation_0-mlogloss:0.18709
# [310]	validation_0-mlogloss:0.18684
# [312]	validation_0-mlogloss:0.18664
# [314]	validation_0-mlogloss:0.18644
# [316]	validation_0-mlogloss:0.18623
# [318]	validation_0-mlogloss:0.18608
# [320]	validation_0-mlogloss:0.18597
# [322]	validation_0-mlogloss:0.18567
# [324]	validation_0-mlogloss:0.18553
# [326]	validation_0-mlogloss:0.18530
# [328]	validation_0-mlogloss:0.18509
# [330]	validation_0-mlogloss:0.18489
# [332]	validation_0-mlogloss:0.18468
# [334]	validation_0-mlogloss:0.18438
# [336]	validation_0-mlogloss:0.18421
# [338]	validation_0-mlogloss:0.18405
# [340]	validation_0-mlogloss:0.18394
# [342]	validation_0-mlogloss:0.18366
# [344]	validation_0-mlogloss:0.18352
# [346]	validation_0-mlogloss:0.18344
# [348]	validation_0-mlogloss:0.18326
# [350]	validation_0-mlogloss:0.18319
# [352]	validation_0-mlogloss:0.18306
# [354]	validation_0-mlogloss:0.18300
# [356]	validation_0-mlogloss:0.18282
# [358]	validation_0-mlogloss:0.18273
# [360]	validation_0-mlogloss:0.18259
# [362]	validation_0-mlogloss:0.18250
# [364]	validation_0-mlogloss:0.18226
# [366]	validation_0-mlogloss:0.18211
# [368]	validation_0-mlogloss:0.18200
# [370]	validation_0-mlogloss:0.18176
# [372]	validation_0-mlogloss:0.18158
# [374]	validation_0-mlogloss:0.18130
# [376]	validation_0-mlogloss:0.18107
# [378]	validation_0-mlogloss:0.18087
# [380]	validation_0-mlogloss:0.18079
# [382]	validation_0-mlogloss:0.18063
# [384]	validation_0-mlogloss:0.18045
# [386]	validation_0-mlogloss:0.18033
# [388]	validation_0-mlogloss:0.18021
# [390]	validation_0-mlogloss:0.18020
# [392]	validation_0-mlogloss:0.18014
# [394]	validation_0-mlogloss:0.18005
# [396]	validation_0-mlogloss:0.17992
# [398]	validation_0-mlogloss:0.17984
# [400]	validation_0-mlogloss:0.17965
# [402]	validation_0-mlogloss:0.17946
# [404]	validation_0-mlogloss:0.17926
# [406]	validation_0-mlogloss:0.17916
# [408]	validation_0-mlogloss:0.17910
# [410]	validation_0-mlogloss:0.17903
# [412]	validation_0-mlogloss:0.17894
# [414]	validation_0-mlogloss:0.17876
# [416]	validation_0-mlogloss:0.17862
# [418]	validation_0-mlogloss:0.17851
# [420]	validation_0-mlogloss:0.17840
# [422]	validation_0-mlogloss:0.17833
# [424]	validation_0-mlogloss:0.17830
# [426]	validation_0-mlogloss:0.17814
# [428]	validation_0-mlogloss:0.17812
# [430]	validation_0-mlogloss:0.17794
# [432]	validation_0-mlogloss:0.17794
# [434]	validation_0-mlogloss:0.17785
# [436]	validation_0-mlogloss:0.17773
# [438]	validation_0-mlogloss:0.17753
# [440]	validation_0-mlogloss:0.17750
# [442]	validation_0-mlogloss:0.17739
# [444]	validation_0-mlogloss:0.17734
# [446]	validation_0-mlogloss:0.17717
# [448]	validation_0-mlogloss:0.17699
# [450]	validation_0-mlogloss:0.17689
# [452]	validation_0-mlogloss:0.17676
# [454]	validation_0-mlogloss:0.17669
# [456]	validation_0-mlogloss:0.17663
# [458]	validation_0-mlogloss:0.17654
# [460]	validation_0-mlogloss:0.17650
# [462]	validation_0-mlogloss:0.17637
# [464]	validation_0-mlogloss:0.17633
# [466]	validation_0-mlogloss:0.17621
# [468]	validation_0-mlogloss:0.17614
# [470]	validation_0-mlogloss:0.17601
# [472]	validation_0-mlogloss:0.17603
# [474]	validation_0-mlogloss:0.17597
# [476]	validation_0-mlogloss:0.17582
# [478]	validation_0-mlogloss:0.17573
# [480]	validation_0-mlogloss:0.17558
# [482]	validation_0-mlogloss:0.17556
# [484]	validation_0-mlogloss:0.17547
# [486]	validation_0-mlogloss:0.17534
# [488]	validation_0-mlogloss:0.17531
# [490]	validation_0-mlogloss:0.17533
# [492]	validation_0-mlogloss:0.17519
# [494]	validation_0-mlogloss:0.17511
# [496]	validation_0-mlogloss:0.17511
# [498]	validation_0-mlogloss:0.17506
# [500]	validation_0-mlogloss:0.17505
# [502]	validation_0-mlogloss:0.17491
# [504]	validation_0-mlogloss:0.17490
# [506]	validation_0-mlogloss:0.17492
# [508]	validation_0-mlogloss:0.17485
# [510]	validation_0-mlogloss:0.17482
# [512]	validation_0-mlogloss:0.17477
# [514]	validation_0-mlogloss:0.17472
# [516]	validation_0-mlogloss:0.17469
# [518]	validation_0-mlogloss:0.17469
# [520]	validation_0-mlogloss:0.17463
# [522]	validation_0-mlogloss:0.17463
# [524]	validation_0-mlogloss:0.17461
# [526]	validation_0-mlogloss:0.17462
# [528]	validation_0-mlogloss:0.17460
# [530]	validation_0-mlogloss:0.17454
# [532]	validation_0-mlogloss:0.17449
# [534]	validation_0-mlogloss:0.17448
# [536]	validation_0-mlogloss:0.17446
# [538]	validation_0-mlogloss:0.17450
# [540]	validation_0-mlogloss:0.17448
# [542]	validation_0-mlogloss:0.17442
# [544]	validation_0-mlogloss:0.17438
# [546]	validation_0-mlogloss:0.17431
# [548]	validation_0-mlogloss:0.17425
# [550]	validation_0-mlogloss:0.17424
# [552]	validation_0-mlogloss:0.17423
# [554]	validation_0-mlogloss:0.17421
# [556]	validation_0-mlogloss:0.17418
# [558]	validation_0-mlogloss:0.17414
# [560]	validation_0-mlogloss:0.17411
# [562]	validation_0-mlogloss:0.17404
# [564]	validation_0-mlogloss:0.17411
# [566]	validation_0-mlogloss:0.17408
# [568]	validation_0-mlogloss:0.17405
# [570]	validation_0-mlogloss:0.17408
# [572]	validation_0-mlogloss:0.17403
# [574]	validation_0-mlogloss:0.17406
# [576]	validation_0-mlogloss:0.17405
# [578]	validation_0-mlogloss:0.17410
# [580]	validation_0-mlogloss:0.17404
# [582]	validation_0-mlogloss:0.17407
# [584]	validation_0-mlogloss:0.17405
# [586]	validation_0-mlogloss:0.17405
# [588]	validation_0-mlogloss:0.17408
# [590]	validation_0-mlogloss:0.17399
# [592]	validation_0-mlogloss:0.17404
# [594]	validation_0-mlogloss:0.17401
# [596]	validation_0-mlogloss:0.17400
# [598]	validation_0-mlogloss:0.17399
# [600]	validation_0-mlogloss:0.17408
# [602]	validation_0-mlogloss:0.17412
# [604]	validation_0-mlogloss:0.17410
# [606]	validation_0-mlogloss:0.17409
# [608]	validation_0-mlogloss:0.17410
# [610]	validation_0-mlogloss:0.17410
# [612]	validation_0-mlogloss:0.17405
# [614]	validation_0-mlogloss:0.17406
# [616]	validation_0-mlogloss:0.17407
# [618]	validation_0-mlogloss:0.17411
# [620]	validation_0-mlogloss:0.17407
# [622]	validation_0-mlogloss:0.17406
# [624]	validation_0-mlogloss:0.17412
# [626]	validation_0-mlogloss:0.17411
# [628]	validation_0-mlogloss:0.17409
# [630]	validation_0-mlogloss:0.17403
# [632]	validation_0-mlogloss:0.17398
# [634]	validation_0-mlogloss:0.17402
# [636]	validation_0-mlogloss:0.17399
# [638]	validation_0-mlogloss:0.17394
# [640]	validation_0-mlogloss:0.17394
# [642]	validation_0-mlogloss:0.17402
# [644]	validation_0-mlogloss:0.17396
# [646]	validation_0-mlogloss:0.17398
# [648]	validation_0-mlogloss:0.17394
# [650]	validation_0-mlogloss:0.17390
# [652]	validation_0-mlogloss:0.17398
# [654]	validation_0-mlogloss:0.17399
# [656]	validation_0-mlogloss:0.17404
# [658]	validation_0-mlogloss:0.17412
# [660]	validation_0-mlogloss:0.17413
# [662]	validation_0-mlogloss:0.17412
# [664]	validation_0-mlogloss:0.17416
# [666]	validation_0-mlogloss:0.17417
# [668]	validation_0-mlogloss:0.17421
# [670]	validation_0-mlogloss:0.17423
# [672]	validation_0-mlogloss:0.17414
# [674]	validation_0-mlogloss:0.17414
# [676]	validation_0-mlogloss:0.17410
# [678]	validation_0-mlogloss:0.17407
# [680]	validation_0-mlogloss:0.17405
# [682]	validation_0-mlogloss:0.17410
# [684]	validation_0-mlogloss:0.17421
# [686]	validation_0-mlogloss:0.17419
# [688]	validation_0-mlogloss:0.17424
# [690]	validation_0-mlogloss:0.17422
# [692]	validation_0-mlogloss:0.17426
# [694]	validation_0-mlogloss:0.17420
# [696]	validation_0-mlogloss:0.17426
# [698]	validation_0-mlogloss:0.17425
# [699]	validation_0-mlogloss:0.17433
# #########################
# ### Fold 5
# ### Train size 96000 Valid size 24000
# #########################
# [0]	validation_0-mlogloss:1.70836
# [2]	validation_0-mlogloss:1.38341
# [4]	validation_0-mlogloss:1.16307
# [6]	validation_0-mlogloss:1.00189
# [8]	validation_0-mlogloss:0.87970
# [10]	validation_0-mlogloss:0.78195
# [12]	validation_0-mlogloss:0.70377
# [14]	validation_0-mlogloss:0.64000
# [16]	validation_0-mlogloss:0.58740
# [18]	validation_0-mlogloss:0.54387
# [20]	validation_0-mlogloss:0.50795
# [22]	validation_0-mlogloss:0.47761
# [24]	validation_0-mlogloss:0.45245
# [26]	validation_0-mlogloss:0.43069
# [28]	validation_0-mlogloss:0.41210
# [30]	validation_0-mlogloss:0.39616
# [32]	validation_0-mlogloss:0.38264
# [34]	validation_0-mlogloss:0.37060
# [36]	validation_0-mlogloss:0.36030
# [38]	validation_0-mlogloss:0.35074
# [40]	validation_0-mlogloss:0.34225
# [42]	validation_0-mlogloss:0.33482
# [44]	validation_0-mlogloss:0.32784
# [46]	validation_0-mlogloss:0.32122
# [48]	validation_0-mlogloss:0.31570
# [50]	validation_0-mlogloss:0.31069
# [52]	validation_0-mlogloss:0.30593
# [54]	validation_0-mlogloss:0.30157
# [56]	validation_0-mlogloss:0.29745
# [58]	validation_0-mlogloss:0.29354
# [60]	validation_0-mlogloss:0.28993
# [62]	validation_0-mlogloss:0.28643
# [64]	validation_0-mlogloss:0.28343
# [66]	validation_0-mlogloss:0.28010
# [68]	validation_0-mlogloss:0.27736
# [70]	validation_0-mlogloss:0.27483
# [72]	validation_0-mlogloss:0.27207
# [74]	validation_0-mlogloss:0.26953
# [76]	validation_0-mlogloss:0.26727
# [78]	validation_0-mlogloss:0.26482
# [80]	validation_0-mlogloss:0.26260
# [82]	validation_0-mlogloss:0.26032
# [84]	validation_0-mlogloss:0.25833
# [86]	validation_0-mlogloss:0.25636
# [88]	validation_0-mlogloss:0.25459
# [90]	validation_0-mlogloss:0.25303
# [92]	validation_0-mlogloss:0.25103
# [94]	validation_0-mlogloss:0.24948
# [96]	validation_0-mlogloss:0.24780
# [98]	validation_0-mlogloss:0.24636
# [100]	validation_0-mlogloss:0.24488
# [102]	validation_0-mlogloss:0.24331
# [104]	validation_0-mlogloss:0.24176
# [106]	validation_0-mlogloss:0.24013
# [108]	validation_0-mlogloss:0.23880
# [110]	validation_0-mlogloss:0.23747
# [112]	validation_0-mlogloss:0.23594
# [114]	validation_0-mlogloss:0.23468
# [116]	validation_0-mlogloss:0.23357
# [118]	validation_0-mlogloss:0.23228
# [120]	validation_0-mlogloss:0.23132
# [122]	validation_0-mlogloss:0.23026
# [124]	validation_0-mlogloss:0.22908
# [126]	validation_0-mlogloss:0.22829
# [128]	validation_0-mlogloss:0.22730
# [130]	validation_0-mlogloss:0.22637
# [132]	validation_0-mlogloss:0.22533
# [134]	validation_0-mlogloss:0.22432
# [136]	validation_0-mlogloss:0.22353
# [138]	validation_0-mlogloss:0.22259
# [140]	validation_0-mlogloss:0.22180
# [142]	validation_0-mlogloss:0.22098
# [144]	validation_0-mlogloss:0.22016
# [146]	validation_0-mlogloss:0.21936
# [148]	validation_0-mlogloss:0.21843
# [150]	validation_0-mlogloss:0.21772
# [152]	validation_0-mlogloss:0.21689
# [154]	validation_0-mlogloss:0.21618
# [156]	validation_0-mlogloss:0.21515
# [158]	validation_0-mlogloss:0.21442
# [160]	validation_0-mlogloss:0.21365
# [162]	validation_0-mlogloss:0.21279
# [164]	validation_0-mlogloss:0.21217
# [166]	validation_0-mlogloss:0.21156
# [168]	validation_0-mlogloss:0.21087
# [170]	validation_0-mlogloss:0.21024
# [172]	validation_0-mlogloss:0.20976
# [174]	validation_0-mlogloss:0.20906
# [176]	validation_0-mlogloss:0.20853
# [178]	validation_0-mlogloss:0.20812
# [180]	validation_0-mlogloss:0.20742
# [182]	validation_0-mlogloss:0.20684
# [184]	validation_0-mlogloss:0.20639
# [186]	validation_0-mlogloss:0.20576
# [188]	validation_0-mlogloss:0.20515
# [190]	validation_0-mlogloss:0.20470
# [192]	validation_0-mlogloss:0.20415
# [194]	validation_0-mlogloss:0.20374
# [196]	validation_0-mlogloss:0.20332
# [198]	validation_0-mlogloss:0.20280
# [200]	validation_0-mlogloss:0.20242
# [202]	validation_0-mlogloss:0.20180
# [204]	validation_0-mlogloss:0.20144
# [206]	validation_0-mlogloss:0.20095
# [208]	validation_0-mlogloss:0.20052
# [210]	validation_0-mlogloss:0.20014
# [212]	validation_0-mlogloss:0.19961
# [214]	validation_0-mlogloss:0.19930
# [216]	validation_0-mlogloss:0.19870
# [218]	validation_0-mlogloss:0.19825
# [220]	validation_0-mlogloss:0.19775
# [222]	validation_0-mlogloss:0.19734
# [224]	validation_0-mlogloss:0.19697
# [226]	validation_0-mlogloss:0.19664
# [228]	validation_0-mlogloss:0.19628
# [230]	validation_0-mlogloss:0.19593
# [232]	validation_0-mlogloss:0.19557
# [234]	validation_0-mlogloss:0.19530
# [236]	validation_0-mlogloss:0.19489
# [238]	validation_0-mlogloss:0.19446
# [240]	validation_0-mlogloss:0.19420
# [242]	validation_0-mlogloss:0.19398
# [244]	validation_0-mlogloss:0.19381
# [246]	validation_0-mlogloss:0.19355
# [248]	validation_0-mlogloss:0.19312
# [250]	validation_0-mlogloss:0.19276
# [252]	validation_0-mlogloss:0.19242
# [254]	validation_0-mlogloss:0.19219
# [256]	validation_0-mlogloss:0.19185
# [258]	validation_0-mlogloss:0.19157
# [260]	validation_0-mlogloss:0.19125
# [262]	validation_0-mlogloss:0.19096
# [264]	validation_0-mlogloss:0.19061
# [266]	validation_0-mlogloss:0.19038
# [268]	validation_0-mlogloss:0.19010
# [270]	validation_0-mlogloss:0.18993
# [272]	validation_0-mlogloss:0.18969
# [274]	validation_0-mlogloss:0.18950
# [276]	validation_0-mlogloss:0.18925
# [278]	validation_0-mlogloss:0.18908
# [280]	validation_0-mlogloss:0.18864
# [282]	validation_0-mlogloss:0.18832
# [284]	validation_0-mlogloss:0.18812
# [286]	validation_0-mlogloss:0.18787
# [288]	validation_0-mlogloss:0.18767
# [290]	validation_0-mlogloss:0.18737
# [292]	validation_0-mlogloss:0.18713
# [294]	validation_0-mlogloss:0.18689
# [296]	validation_0-mlogloss:0.18676
# [298]	validation_0-mlogloss:0.18645
# [300]	validation_0-mlogloss:0.18622
# [302]	validation_0-mlogloss:0.18591
# [304]	validation_0-mlogloss:0.18575
# [306]	validation_0-mlogloss:0.18560
# [308]	validation_0-mlogloss:0.18539
# [310]	validation_0-mlogloss:0.18513
# [312]	validation_0-mlogloss:0.18481
# [314]	validation_0-mlogloss:0.18453
# [316]	validation_0-mlogloss:0.18438
# [318]	validation_0-mlogloss:0.18424
# [320]	validation_0-mlogloss:0.18393
# [322]	validation_0-mlogloss:0.18376
# [324]	validation_0-mlogloss:0.18360
# [326]	validation_0-mlogloss:0.18338
# [328]	validation_0-mlogloss:0.18316
# [330]	validation_0-mlogloss:0.18298
# [332]	validation_0-mlogloss:0.18271
# [334]	validation_0-mlogloss:0.18260
# [336]	validation_0-mlogloss:0.18256
# [338]	validation_0-mlogloss:0.18246
# [340]	validation_0-mlogloss:0.18231
# [342]	validation_0-mlogloss:0.18210
# [344]	validation_0-mlogloss:0.18188
# [346]	validation_0-mlogloss:0.18178
# [348]	validation_0-mlogloss:0.18164
# [350]	validation_0-mlogloss:0.18144
# [352]	validation_0-mlogloss:0.18130
# [354]	validation_0-mlogloss:0.18117
# [356]	validation_0-mlogloss:0.18102
# [358]	validation_0-mlogloss:0.18088
# [360]	validation_0-mlogloss:0.18072
# [362]	validation_0-mlogloss:0.18056
# [364]	validation_0-mlogloss:0.18034
# [366]	validation_0-mlogloss:0.18030
# [368]	validation_0-mlogloss:0.18012
# [370]	validation_0-mlogloss:0.18003
# [372]	validation_0-mlogloss:0.17987
# [374]	validation_0-mlogloss:0.17984
# [376]	validation_0-mlogloss:0.17977
# [378]	validation_0-mlogloss:0.17958
# [380]	validation_0-mlogloss:0.17949
# [382]	validation_0-mlogloss:0.17940
# [384]	validation_0-mlogloss:0.17918
# [386]	validation_0-mlogloss:0.17908
# [388]	validation_0-mlogloss:0.17900
# [390]	validation_0-mlogloss:0.17887
# [392]	validation_0-mlogloss:0.17871
# [394]	validation_0-mlogloss:0.17868
# [396]	validation_0-mlogloss:0.17853
# [398]	validation_0-mlogloss:0.17847
# [400]	validation_0-mlogloss:0.17832
# [402]	validation_0-mlogloss:0.17825
# [404]	validation_0-mlogloss:0.17811
# [406]	validation_0-mlogloss:0.17797
# [408]	validation_0-mlogloss:0.17790
# [410]	validation_0-mlogloss:0.17771
# [412]	validation_0-mlogloss:0.17762
# [414]	validation_0-mlogloss:0.17745
# [416]	validation_0-mlogloss:0.17731
# [418]	validation_0-mlogloss:0.17719
# [420]	validation_0-mlogloss:0.17705
# [422]	validation_0-mlogloss:0.17696
# [424]	validation_0-mlogloss:0.17683
# [426]	validation_0-mlogloss:0.17677
# [428]	validation_0-mlogloss:0.17662
# [430]	validation_0-mlogloss:0.17660
# [432]	validation_0-mlogloss:0.17654
# [434]	validation_0-mlogloss:0.17646
# [436]	validation_0-mlogloss:0.17636
# [438]	validation_0-mlogloss:0.17627
# [440]	validation_0-mlogloss:0.17623
# [442]	validation_0-mlogloss:0.17610
# [444]	validation_0-mlogloss:0.17597
# [446]	validation_0-mlogloss:0.17586
# [448]	validation_0-mlogloss:0.17582
# [450]	validation_0-mlogloss:0.17582
# [452]	validation_0-mlogloss:0.17577
# [454]	validation_0-mlogloss:0.17578
# [456]	validation_0-mlogloss:0.17568
# [458]	validation_0-mlogloss:0.17566
# [460]	validation_0-mlogloss:0.17541
# [462]	validation_0-mlogloss:0.17536
# [464]	validation_0-mlogloss:0.17533
# [466]	validation_0-mlogloss:0.17531
# [468]	validation_0-mlogloss:0.17526
# [470]	validation_0-mlogloss:0.17522
# [472]	validation_0-mlogloss:0.17518
# [474]	validation_0-mlogloss:0.17511
# [476]	validation_0-mlogloss:0.17499
# [478]	validation_0-mlogloss:0.17495
# [480]	validation_0-mlogloss:0.17494
# [482]	validation_0-mlogloss:0.17486
# [484]	validation_0-mlogloss:0.17476
# [486]	validation_0-mlogloss:0.17462
# [488]	validation_0-mlogloss:0.17446
# [490]	validation_0-mlogloss:0.17438
# [492]	validation_0-mlogloss:0.17437
# [494]	validation_0-mlogloss:0.17425
# [496]	validation_0-mlogloss:0.17420
# [498]	validation_0-mlogloss:0.17414
# [500]	validation_0-mlogloss:0.17408
# [502]	validation_0-mlogloss:0.17396
# [504]	validation_0-mlogloss:0.17396
# [506]	validation_0-mlogloss:0.17392
# [508]	validation_0-mlogloss:0.17387
# [510]	validation_0-mlogloss:0.17380
# [512]	validation_0-mlogloss:0.17383
# [514]	validation_0-mlogloss:0.17370
# [516]	validation_0-mlogloss:0.17370
# [518]	validation_0-mlogloss:0.17362
# [520]	validation_0-mlogloss:0.17352
# [522]	validation_0-mlogloss:0.17344
# [524]	validation_0-mlogloss:0.17341
# [526]	validation_0-mlogloss:0.17343
# [528]	validation_0-mlogloss:0.17345
# [530]	validation_0-mlogloss:0.17338
# [532]	validation_0-mlogloss:0.17329
# [534]	validation_0-mlogloss:0.17329
# [536]	validation_0-mlogloss:0.17322
# [538]	validation_0-mlogloss:0.17318
# [540]	validation_0-mlogloss:0.17315
# [542]	validation_0-mlogloss:0.17312
# [544]	validation_0-mlogloss:0.17314
# [546]	validation_0-mlogloss:0.17308
# [548]	validation_0-mlogloss:0.17301
# [550]	validation_0-mlogloss:0.17292
# [552]	validation_0-mlogloss:0.17287
# [554]	validation_0-mlogloss:0.17284
# [556]	validation_0-mlogloss:0.17278
# [558]	validation_0-mlogloss:0.17280
# [560]	validation_0-mlogloss:0.17276
# [562]	validation_0-mlogloss:0.17269
# [564]	validation_0-mlogloss:0.17269
# [566]	validation_0-mlogloss:0.17267
# [568]	validation_0-mlogloss:0.17267
# [570]	validation_0-mlogloss:0.17267
# [572]	validation_0-mlogloss:0.17264
# [574]	validation_0-mlogloss:0.17263
# [576]	validation_0-mlogloss:0.17262
# [578]	validation_0-mlogloss:0.17261
# [580]	validation_0-mlogloss:0.17264
# [582]	validation_0-mlogloss:0.17259
# [584]	validation_0-mlogloss:0.17259
# [586]	validation_0-mlogloss:0.17257
# [588]	validation_0-mlogloss:0.17258
# [590]	validation_0-mlogloss:0.17260
# [592]	validation_0-mlogloss:0.17258
# [594]	validation_0-mlogloss:0.17254
# [596]	validation_0-mlogloss:0.17255
# [598]	validation_0-mlogloss:0.17251
# [600]	validation_0-mlogloss:0.17247
# [602]	validation_0-mlogloss:0.17243
# [604]	validation_0-mlogloss:0.17241
# [606]	validation_0-mlogloss:0.17237
# [608]	validation_0-mlogloss:0.17231
# [610]	validation_0-mlogloss:0.17233
# [612]	validation_0-mlogloss:0.17238
# [614]	validation_0-mlogloss:0.17244
# [616]	validation_0-mlogloss:0.17234
# [618]	validation_0-mlogloss:0.17238
# [620]	validation_0-mlogloss:0.17229
# [622]	validation_0-mlogloss:0.17229
# [624]	validation_0-mlogloss:0.17225
# [626]	validation_0-mlogloss:0.17222
# [628]	validation_0-mlogloss:0.17216
# [630]	validation_0-mlogloss:0.17220
# [632]	validation_0-mlogloss:0.17220
# [634]	validation_0-mlogloss:0.17227
# [636]	validation_0-mlogloss:0.17226
# [638]	validation_0-mlogloss:0.17225
# [640]	validation_0-mlogloss:0.17229
# [642]	validation_0-mlogloss:0.17235
# [644]	validation_0-mlogloss:0.17235
# [646]	validation_0-mlogloss:0.17231
# [648]	validation_0-mlogloss:0.17234
# [650]	validation_0-mlogloss:0.17233
# [652]	validation_0-mlogloss:0.17240
# [654]	validation_0-mlogloss:0.17244
# [656]	validation_0-mlogloss:0.17240
# [658]	validation_0-mlogloss:0.17238
# [660]	validation_0-mlogloss:0.17239
# [662]	validation_0-mlogloss:0.17234
# [664]	validation_0-mlogloss:0.17233
# [666]	validation_0-mlogloss:0.17234
# [668]	validation_0-mlogloss:0.17234
# [670]	validation_0-mlogloss:0.17236
# [672]	validation_0-mlogloss:0.17233
# [674]	validation_0-mlogloss:0.17230
# [676]	validation_0-mlogloss:0.17233
# [678]	validation_0-mlogloss:0.17239
# [680]	validation_0-mlogloss:0.17235
# [682]	validation_0-mlogloss:0.17237
# [684]	validation_0-mlogloss:0.17240
# [686]	validation_0-mlogloss:0.17241
# [688]	validation_0-mlogloss:0.17244
# [690]	validation_0-mlogloss:0.17243
# [692]	validation_0-mlogloss:0.17236
# [694]	validation_0-mlogloss:0.17239
# [696]	validation_0-mlogloss:0.17231
# [698]	validation_0-mlogloss:0.17231
# [699]	validation_0-mlogloss:0.17235
# [0.9372083333333333, 0.9375416666666667, 0.9375833333333333, 0.9380833333333334, 0.9390416666666667]

# %% [markdown]
# Results on cross validation with 5 splits. <br/>
# On average, model with parameters {'colsample_bytree': 0.5, 'gamma': 0.0, 'learning_rate': 0.1, 'max_depth': 5, 'n_estimators': 700, 'num_class': 7, 'objective': 'multi:softmax', 'reg_alpha': 1e-05, 'reg_lambda': 1e-05} performed with such accuracies: </br>
# Accuracy on cross validation: <br/>
# [0.9372083333333333, 0.9375416666666667, 0.9375833333333333, 0.9380833333333334, 0.9390416666666667]

# %% [markdown]
# Now we train our model with these parameters on the whole dataset

# %%
xgb_model = xgb.XGBClassifier(seed=0, 
                            colsample_bytree=space_eval(space, best)['colsample_bytree'], 
                            objective=space_eval(space, best)['objective'],
                            gamma=space_eval(space, best)['gamma'], 
                            learning_rate=space_eval(space, best)['learning_rate'], 
                            max_depth=space_eval(space, best)['max_depth'], 
                            reg_alpha=space_eval(space, best)['reg_alpha'],
                            reg_lambda=space_eval(space, best)['reg_lambda'],
                            n_estimators=space_eval(space, best)['n_estimators'],
                            tree_method='gpu_hist',
                            predictor='gpu_predictor',
                            nthread=6,
                            num_class=7
                            )

xgb_model.fit(full_df, labels,verbose=2)
y_pred = xgb_model.predict(full_df)
# scores.append(mean_squared_error(labels,y_pred))


print('-- Model Report --')
print('XGBoost Accuracy: '+ str(accuracy_score(y_pred, labels)))
print('XGBoost F1-Score (Micro): '+str(f1_score(y_pred,labels,average='micro')))
print(classification_report(labels, y_pred))

xgb_model.save_model(f'XGB_final_model_best_params.xgb')
# Out:
# -- Model Report --
# XGBoost Accuracy: 0.9995333333333334
# XGBoost F1-Score (Micro): 0.9995333333333334
#               precision    recall  f1-score   support
#
#            0       1.00      1.00      1.00     85358
#            1       1.00      1.00      1.00      5833
#            2       1.00      1.00      1.00      8954
#            3       1.00      1.00      1.00      8198
#            4       1.00      1.00      1.00      2324
#            5       1.00      1.00      1.00      5111
#            6       1.00      1.00      1.00      4222
#
#     accuracy                           1.00    120000
#    macro avg       1.00      1.00      1.00    120000
# weighted avg       1.00      1.00      1.00    120000

# %% [markdown]
# On this point, accuracy of our trained model is 99%, which is almost perfect. <br/>
# We will see then how our model performs on unseen data, when we will get data for final classification
#
#
# -- Model Report --
# XGBoost Accuracy: 0.9995333333333334
# XGBoost F1-Score (Micro): 0.9995333333333334
#               precision    recall  f1-score   support
#
#            0       1.00      1.00      1.00     85358
#            1       1.00      1.00      1.00      5833
#            2       1.00      1.00      1.00      8954
#            3       1.00      1.00      1.00      8198
#            4       1.00      1.00      1.00      2324
#            5       1.00      1.00      1.00      5111
#            6       1.00      1.00      1.00      4222
#
#     accuracy                           1.00    120000
#    macro avg       1.00      1.00      1.00    120000
# weighted avg       1.00      1.00      1.00    120000
